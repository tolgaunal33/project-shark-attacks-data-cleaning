# %%
pip install openpyxl
# Out:
# python(34773) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Requirement already satisfied: openpyxl in /opt/anaconda3/lib/python3.12/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/lib/python3.12/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt


df = pd.read_excel('/Users/cha/Documents/Ironhack2/UNIT 2/Document - Shark Attacks/GSAF5.xls')
df.head()
# Out:
#           Date    Year        Type    Country              State  \
# 0  15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1  04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2  02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3  25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4  14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
#
#                            Location  Activity                 Name Sex  Age  \
# 0                     Bargara Beach  Swimming       Brooklyn Sauer   F   13
# 1                Old Man's, Waikiki   Surfing        Matthew White   M  NaN
# 2                    Rainbows, Oahu  Swimming                  NaN   F   11
# 3        Sandlnd Island, Jurian Bay       NaN               female   F   46
# 4  Vaitarna River, Palghar District   Fishing  Vicky Suresh Govari   M   32
#
#    ...        Species                      Source  pdf href formula href  \
# 0  ...     Tiger shark      Yahoo News, 3/15/2024  NaN          NaN  NaN
# 1  ...  Tiger shark 8'          Surfer, 3/6/2024F  NaN          NaN  NaN
# 2  ...  3' to 4' shark  Hawaii News Now, 3/4/2024  NaN          NaN  NaN
# 3  ...     Tiger shark        WA Today, 2/26/2024  NaN          NaN  NaN
# 4  ...  Bull shark, 7'  Times of India, 2/14/2024  NaN          NaN  NaN
#
#   Case Number Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0         NaN           NaN            NaN         NaN         NaN
# 1         NaN           NaN            NaN         NaN         NaN
# 2         NaN           NaN            NaN         NaN         NaN
# 3         NaN           NaN            NaN         NaN         NaN
# 4         NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#      Date  Year Type Country State Location Activity Name  Sex  Age  ...  \
# 6964  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN  ...
# 6965  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN  ...
# 6966  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN  ...
# 6967  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN  ...
# 6968  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN  ...
#
#      Species  Source  pdf                                       href formula  \
# 6964      NaN    NaN  NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6965      NaN    NaN  NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6966      NaN    NaN  NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6967      NaN    NaN  NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6968      NaN    NaN  NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#      href Case Number Case Number.1 original order Unnamed: 21 Unnamed: 22
# 6964  NaN         NaN           NaN            NaN         NaN         NaN
# 6965  NaN         NaN           NaN            NaN         NaN         NaN
# 6966  NaN         NaN           NaN            NaN         NaN         NaN
# 6967  NaN         NaN           NaN            NaN         NaN         NaN
# 6968  NaN         NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 23 columns]

# %%
df.sample(15)
# Out:
#                       Date    Year          Type               Country  \
# 6379           20-Jan-1887  1887.0  Sea Disaster                BRAZIL
# 5118           1950 - 1951  1950.0    Unprovoked               LIBERIA
# 2051           02-Sep-2006  2006.0    Unprovoked                   USA
# 1762           17-Mar-2009  2009.0    Unprovoked                   USA
# 6685           26-Dec-1845  1845.0    Unprovoked             AUSTRALIA
# 1730           27-Jun-2009  2009.0    Unprovoked             AUSTRALIA
# 6558  Reported 04-Jan-1868  1868.0  Sea Disaster             AUSTRALIA
# 4021            4-Apr-1970  1970.0    Unprovoked               GRENADA
# 2563           08-May-2001  2001.0    Unprovoked          SOUTH AFRICA
# 4558           06-Jan-1961  1961.0      Provoked             AUSTRALIA
# 5657           14-Jan-1931  1931.0    Unprovoked             AUSTRALIA
# 143            17-Aug-2022  2022.0    Unprovoked             AUSTRALIA
# 5589  Reported 26-Aug-1933  1933.0    Unprovoked                   USA
# 6476           02-Sep-1878  1878.0  Sea Disaster  SOUTH ATLANTIC OCEAN
# 2186           13-Jul-2005  2005.0    Unprovoked                   USA
#
#                              State                          Location  \
# 6379                       Alagoas                            Maceió
# 5118                   Montserrado                          Monrovia
# 2051                       Florida  New Smyrna Beach, Volusia County
# 1762                        Hawaii                Alenuihaha Channel
# 6685               New South Wales                        Newcastle
# 1730               New South Wales          Seven Mile Beach, Gerroa
# 6558               South Australia          Belfast (now Port Fairy)
# 4021             St. Andrew Parish                         Grenville
# 2563         Eastern Cape Province                       East London
# 4558            Northern Territory         Stokes Hill Wharf, Darwin
# 5657                 Torres Strait                               NaN
# 143                New South Wales                     Coffs Harbour
# 5589                   Connecticut                      Mystic River
# 6476  Off the coast of West Africa                               NaN
# 2186                         Texas    Port Bolivar, Galveston County
#
#                                                Activity  \
# 6379  The passenger ship Kapuna was run down the ore...
# 5118              Defecating in water beneath the docks
# 2051                                           Swimming
# 1762                                           Swimming
# 6685                                            Fishing
# 1730                                            Surfing
# 6558                                            Fishing
# 4021                                           Swimming
# 2563                                            Surfing
# 4558                                            Fishing
# 5657                                       Pearl diving
# 143                                            Kayaking
# 5589                                           Swimming
# 6476  Boat with 5 men capsized while returning to th...
# 2186                    Holding onto an inflatable boat
#
#                                                   Name  Sex       Age  ...  \
# 6379                                           Whittle    M       NaN  ...
# 5118                                     a dock worker    M       NaN  ...
# 2051                                              male    M  12 or 13  ...
# 1762                                    Mike Spaulding    M        61  ...
# 6685                                     John Williams    M       NaN  ...
# 1730                                          Les Wade    M        52  ...
# 6558  boat, occupants: John Griffiths & Thomas Johnson  NaN       NaN  ...
# 4021                                      Rudolf Daily    M        14  ...
# 2563                                  David van Staden    M        26  ...
# 4558                                    Arthur Hopkins    M       NaN  ...
# 5657                                 Albertus, a Malay    M       NaN  ...
# 143                                       John Vincent    M       NaN  ...
# 5589                                      Helen Clarke    F       NaN  ...
# 6476                                               NaN    M       NaN  ...
# 2186                                       Lydia Paulk    F        14  ...
#
#                                          Species   \
# 6379                                          NaN
# 5118                                          NaN
# 2051                                          NaN
# 1762      Thought to involve a cookiecutter shark
# 6685                                          NaN
# 1730  Thought to involve a Bronze whale shark, 2m
# 6558                                          NaN
# 4021                                          NaN
# 2563       White shark, 2.7 m to 3 m [9' to 10']
# 4558                Hammerhead shark, 1.8 m [6']
# 5657                                          NaN
# 143                              White shark, 3 m
# 5589                                          NaN
# 6476                                          NaN
# 2186                                   [4' to 5']
#
#                                                  Source  \
# 6379                        Brisbane Courier, 4/14/1887
# 5118                                       G. C. Miller
# 2051                                 S. Petersohn, GSAF
# 1762                     B. Perry, Maui News, 3/18/2009
# 6685  The Maitland Mercury & Hunter River General Ad...
# 1730                          Brisbane Times, 6/28/2009
# 6558  Nelson Examiner & New Zealand Chronicle, 4/3/1868
# 4021                                      E. Pace, FSAF
# 2563               East London Daily Dispatch, 5/9/2001
# 4558          Darwin Northern Territory News, 1/10/1961
# 5657                       V.M. Coppleson (1958), p.242
# 143                                      A Currie. GSAF
# 5589                        Hartford Courant, 8/26/1933
# 6476                       Brisbane Courier, 11/19/1878
# 2186                                  C. Creswell, GSAF
#
#                                         pdf  \
# 6379                 1887.01.20-Whittle.pdf
# 5118  1950.00.00.j-Liberian-dock-worker.pdf
# 2051             2006.09.02.b-Child-NSB.pdf
# 1762             2009.03.17.a-Spaulding.pdf
# 6685                1845.12.26-Williams.pdf
# 1730                    2009.06.27-Wade.pdf
# 6558             1868.01.04.R-PortFairy.pdf
# 4021                   1970.04.04-Daily.pdf
# 2563              2001.05.08-Van Staden.pdf
# 4558               1961.01.06.a-Hopkins.pdf
# 5657                1931.01.14-Albertus.pdf
# 143             2022.08.17-CoffsHarbour.pdf
# 5589           1933.08.26.R-HelenClarke.pdf
# 6476              1878.09.02.a-Amerique.pdf
# 2186                   2005.07.13-Paulk.pdf
#
#                                            href formula  \
# 6379  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5118  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2051  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1762  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6685  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1730  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6558  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4021  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2563  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4558  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5657  http://sharkattackfile.net/spreadsheets/pdf_di...
# 143   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5589  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6476  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2186  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   Case Number  \
# 6379  http://sharkattackfile.net/spreadsheets/pdf_di...    1887.01.20
# 5118  http://sharkattackfile.net/spreadsheets/pdf_di...  1950.00.00.j
# 2051  http://sharkattackfile.net/spreadsheets/pdf_di...    2006.09.02
# 1762  http://sharkattackfile.net/spreadsheets/pdf_di...    2009.03.17
# 6685  http://sharkattackfile.net/spreadsheets/pdf_di...    1845.12.26
# 1730  http://sharkattackfile.net/spreadsheets/pdf_di...    2009.06.27
# 6558  http://sharkattackfile.net/spreadsheets/pdf_di...  1868.01.04.R
# 4021  http://sharkattackfile.net/spreadsheets/pdf_di...    1970.04.04
# 2563  http://sharkattackfile.net/spreadsheets/pdf_di...    2001.05.08
# 4558  http://sharkattackfile.net/spreadsheets/pdf_di...  1961.01.06.a
# 5657  http://sharkattackfile.net/spreadsheets/pdf_di...    1931.01.14
# 143   http://sharkattackfile.net/spreadsheets/pdf_di...    2022.08.17
# 5589  http://sharkattackfile.net/spreadsheets/pdf_di...  1933.08.26.R
# 6476  http://sharkattackfile.net/spreadsheets/pdf_di...  1878.09.02.a
# 2186  http://sharkattackfile.net/spreadsheets/pdf_di...    2005.07.13
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 6379    1887.01.20          564.0         NaN         NaN
# 5118  1950.00.00.j         1824.0         NaN         NaN
# 2051    2006.09.02         4891.0         NaN         NaN
# 1762    2009.03.17         5180.0         NaN         NaN
# 6685    1845.12.26          258.0         NaN         NaN
# 1730    2009.06.27         5212.0         NaN         NaN
# 6558  1868.01.04.R          385.0         NaN         NaN
# 4021    1970.04.04         2921.0         NaN         NaN
# 2563    2001.05.08         4379.0         NaN         NaN
# 4558  1961.01.06.a         2384.0         NaN         NaN
# 5657    1931.01.14         1286.0         NaN         NaN
# 143     2022.08.17         6798.0         NaN         NaN
# 5589  1933.08.26.R         1354.0         NaN         NaN
# 6476  1878.09.02.a          467.0         NaN         NaN
# 2186    2005.07.13         4756.0         NaN         NaN
#
# [15 rows x 23 columns]

# %%
print(df.columns)
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Unnamed: 11', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
df["Country"] = df["Country"].str.strip() 
df["Country"] = df["Country"].str.capitalize()

unique_countries = df["Country"].unique()
print(unique_countries)
# Out:
# ['Australia' 'Usa' 'India' 'Trinidad' 'Bahamas' 'South africa' 'Mexico'
#  'New zealand' 'Egypt' 'Belize' 'Philippines' 'Coral sea' 'Spain'
#  'Portugal' 'Samoa' 'Colombia' 'Ecuador' 'French polynesia'
#  'New caledonia' 'Turks and caicos' 'Cuba' 'Brazil' 'Seychelles'
#  'Argentina' 'Fiji' 'Maldives' 'England' 'Japan' 'Indonesia' 'Jamaica'
#  'Thailand' 'Columbia' 'Costa rica' 'British overseas territory' 'Canada'
#  'Jordan' 'St kitts / nevis' 'St martin' 'Papua new guinea'
#  'Reunion island' 'Israel' 'China' 'Ireland' 'Italy' 'Malaysia' 'Libya'
#  nan 'Mauritius' 'Solomon islands' 'St helena, british overseas territory'
#  'Comoros' 'Reunion' 'United kingdom' 'United arab emirates' 'Cape verde'
#  'Dominican republic' 'Cayman islands' 'Aruba' 'Mozambique' 'Puerto rico'
#  'Atlantic ocean' 'Greece' 'St. martin' 'France' 'Trinidad & tobago'
#  'Kiribati' 'Diego garcia' 'Taiwan' 'Palestinian territories' 'Guam'
#  'Nigeria' 'Tonga' 'Scotland' 'Croatia' 'Saudi arabia' 'Chile' 'Antigua'
#  'Kenya' 'Russia' 'Turks & caicos' 'United arab emirates (uae)' 'Azores'
#  'South korea' 'Malta' 'Vietnam' 'Madagascar' 'Panama' 'Somalia' 'Nevis'
#  'British virgin islands' 'Norway' 'Senegal' 'Yemen' 'Gulf of aden'
#  'Sierra leone' 'St. maartin' 'Grand cayman' 'Liberia' 'Vanuatu'
#  'Honduras' 'Venezuela' 'Sri lanka' 'Uruguay' 'Micronesia' 'Caribbean sea'
#  'Okinawa' 'Tanzania' 'Marshall islands' 'Egypt / israel'
#  'Northern arabian sea' 'Hong kong' 'El salvador' 'Angola' 'Bermuda'
#  'Montenegro' 'Iran' 'Tunisia' 'Namibia' 'North atlantic ocean'
#  'South china sea' 'Bangladesh' 'Palau' 'Western samoa' 'Pacific ocean'
#  'British isles' 'Grenada' 'Iraq' 'Turkey' 'Singapore' 'New britain'
#  'Sudan' 'Johnston island' 'South pacific ocean' 'New guinea' 'Red sea'
#  'North pacific ocean' 'Federated states of micronesia'
#  'Mid atlantic ocean' 'Admiralty islands' 'British west indies'
#  'South atlantic ocean' 'Persian gulf' 'Red sea / indian ocean'
#  'North sea' 'Nicaragua' 'Maldive islands' 'American samoa'
#  'Andaman / nicobar islandas' 'Gabon' 'Mayotte' 'The balkans' 'Sudan?'
#  'Martinique' 'Indian ocean' 'Guatemala' 'Netherlands antilles'
#  'Northern mariana islands' 'Iran / iraq' 'Java' 'Central pacific'
#  'Solomon islands / vanuatu' 'Southwest pacific ocean' 'Bay of bengal'
#  'Mid-pacifc ocean' 'Slovenia' 'Curacao' 'Iceland' 'Italy / croatia'
#  'Barbados' 'Monaco' 'Guyana' 'Haiti' 'San domingo' 'Kuwait'
#  'Falkland islands' 'Crete' 'Cyprus' 'West indies' 'Burma' 'Lebanon'
#  'Paraguay' 'British new guinea' 'Ceylon' 'Ocean' 'Georgia' 'Syria'
#  'Tuvalu' 'Indian ocean?' 'Guinea' 'Andaman islands'
#  'Equatorial guinea / cameroon' 'Cook islands' 'Tobago' 'Peru' 'Africa'
#  'Algeria' 'Coast of africa' 'Tasman sea' 'Ghana' 'Greenland'
#  'Mediterranean sea' 'Sweden' 'Roatan' 'Between portugal & india'
#  'Djibouti' 'Bahrein' 'Korea' 'Red sea?' 'Asia?' 'Ceylon (sri lanka)']

# %%
pd.options.display.max_rows = 209

country_count = df["Country"].value_counts()
print(country_count)
# Out:
# Country
# Usa                                      2538
# Australia                                1481
# South africa                              598
# New zealand                               145
# Papua new guinea                          136
# Bahamas                                   136
# Brazil                                    122
# Mexico                                    106
# Italy                                      72
# Fiji                                       70
# New caledonia                              65
# Philippines                                64
# Reunion                                    60
# Egypt                                      51
# Cuba                                       49
# Mozambique                                 46
# Spain                                      46
# India                                      41
# French polynesia                           37
# Japan                                      36
# Croatia                                    35
# Panama                                     32
# Jamaica                                    30
# Solomon islands                            30
# Iran                                       29
# England                                    25
# Greece                                     24
# Hong kong                                  24
# Indonesia                                  24
# Pacific ocean                              19
# Costa rica                                 18
# Tonga                                      18
# Atlantic ocean                             17
# Bermuda                                    16
# Vietnam                                    15
# Vanuatu                                    14
# Canada                                     14
# Sri lanka                                  14
# Marshall islands                           13
# France                                     13
# Thailand                                   12
# Iraq                                       12
# Turkey                                     12
# South atlantic ocean                       12
# Senegal                                    11
# Venezuela                                  11
# Ecuador                                    11
# United kingdom                             11
# Samoa                                      10
# Columbia                                   10
# Kenya                                      10
# New guinea                                 10
# Mauritius                                  10
# Seychelles                                 10
# China                                       9
# Sierra leone                                9
# Taiwan                                      9
# Yemen                                       9
# Scotland                                    8
# South korea                                 8
# Chile                                       8
# Madagascar                                  8
# Tanzania                                    8
# Israel                                      8
# Caribbean sea                               8
# Belize                                      7
# Indian ocean                                7
# Nicaragua                                   7
# Dominican republic                          7
# North pacific ocean                         7
# New britain                                 6
# Somalia                                     6
# Singapore                                   6
# Barbados                                    6
# Okinawa                                     6
# Libya                                       6
# Kiribati                                    6
# Palau                                       5
# Malta                                       5
# Mid atlantic ocean                          5
# Malaysia                                    5
# Reunion island                              5
# Saudi arabia                                5
# Azores                                      5
# North atlantic ocean                        5
# Turks & caicos                              5
# Maldives                                    4
# Portugal                                    4
# El salvador                                 4
# Grenada                                     4
# Uruguay                                     4
# Persian gulf                                4
# Sudan                                       4
# Honduras                                    4
# Guam                                        4
# Burma                                       4
# Russia                                      4
# Nigeria                                     4
# Ceylon                                      3
# Guyana                                      3
# Haiti                                       3
# Tunisia                                     3
# Lebanon                                     3
# Martinique                                  3
# American samoa                              3
# Montenegro                                  3
# Micronesia                                  3
# Trinidad & tobago                           3
# Cape verde                                  3
# Guinea                                      3
# Liberia                                     3
# Southwest pacific ocean                     2
# Argentina                                   2
# Central pacific                             2
# Johnston island                             2
# South pacific ocean                         2
# Crete                                       2
# Colombia                                    2
# West indies                                 2
# Tobago                                      2
# Antigua                                     2
# Peru                                        2
# Iceland                                     2
# Mediterranean sea                           2
# United arab emirates (uae)                  2
# Namibia                                     2
# Ireland                                     2
# Cayman islands                              2
# United arab emirates                        2
# Norway                                      2
# St helena, british overseas territory       2
# Falkland islands                            1
# Djibouti                                    1
# Cyprus                                      1
# Bahrein                                     1
# San domingo                                 1
# Kuwait                                      1
# Roatan                                      1
# Korea                                       1
# Red sea?                                    1
# Monaco                                      1
# Asia?                                       1
# Trinidad                                    1
# Italy / croatia                             1
# Between portugal & india                    1
# Cook islands                                1
# Sweden                                      1
# Tasman sea                                  1
# Curacao                                     1
# Andaman islands                             1
# Africa                                      1
# Indian ocean?                               1
# Algeria                                     1
# Coast of africa                             1
# Tuvalu                                      1
# Paraguay                                    1
# Syria                                       1
# Georgia                                     1
# Ocean                                       1
# Ghana                                       1
# British new guinea                          1
# Equatorial guinea / cameroon                1
# Greenland                                   1
# North sea                                   1
# Slovenia                                    1
# Jordan                                      1
# British isles                               1
# St martin                                   1
# Western samoa                               1
# Bangladesh                                  1
# South china sea                             1
# Angola                                      1
# Northern arabian sea                        1
# Egypt / israel                              1
# Comoros                                     1
# Aruba                                       1
# Grand cayman                                1
# St. maartin                                 1
# Puerto rico                                 1
# Gulf of aden                                1
# St. martin                                  1
# British virgin islands                      1
# Nevis                                       1
# Diego garcia                                1
# Palestinian territories                     1
# St kitts / nevis                            1
# British overseas territory                  1
# Mid-pacifc ocean                            1
# Red sea                                     1
# Bay of bengal                               1
# Solomon islands / vanuatu                   1
# Java                                        1
# Iran / iraq                                 1
# Northern mariana islands                    1
# Netherlands antilles                        1
# Guatemala                                   1
# Coral sea                                   1
# Sudan?                                      1
# The balkans                                 1
# Mayotte                                     1
# Gabon                                       1
# Andaman / nicobar islandas                  1
# Maldive islands                             1
# Red sea / indian ocean                      1
# British west indies                         1
# Admiralty islands                           1
# Federated states of micronesia              1
# Turks and caicos                            1
# Ceylon (sri lanka)                          1
# Name: count, dtype: int64

# %%
country_count = df["Country"].nunique()
print(country_count)
# Out:
# 209

# %%
df["Type"] = df["Type"].str.strip() 
df["Type"] = df["Type"].str.capitalize()

unique_type = df["Type"].unique()
print(unique_type)
# Out:
# ['Unprovoked' 'Provoked' 'Questionable' 'Watercraft' 'Sea disaster' nan
#  '?' 'Unconfirmed' 'Unverified' 'Invalid' 'Under investigation' 'Boat']

# %%
df["Injury"] = df["Injury"].str.strip() 

unique_injury = df["Injury"].unique()
print(unique_injury)
# Out:
# ['Minor injuries to back, abdomen and legs'
#  'No injury, shark bit surfboard' 'Lacerations to left foot' ...
#  'FATAL, leg stripped of flesh'
#  'FATAL, knocked overboard by tail of shark & carried off by shark'
#  'FATAL. "Shark bit him in half, carrying away the lower extremities"']

# %%
pd.options.display.max_rows = 209


injury_count = df["Injury"].value_counts() 
print(injury_count)
# Out:
# Injury
# FATAL                                                                  874
# Foot bitten                                                            100
# Survived                                                                97
# No injury                                                               89
# Leg bitten                                                              84
#                                                                       ...
# PROVOKED INCIDENT Hooked shark pulled onboard bit his arm                1
# FATAL          Hip & upper thigh bitten, femoral artery severed          1
# Left ankle lacerated                                                     1
# No injury, wetsuit torn & board bitten                                   1
# FATAL. "Shark bit him in half, carrying away the lower extremities"      1
# Name: count, Length: 4011, dtype: int64

# %%
shark_fatals = df.query("Injury=='Fatal'")["Country"].sort_values(ascending = False)
shark_fatals
# Out:
# 4402    Seychelles
# 788        Reunion
# 115         Mexico
# 73           Egypt
# 111      Australia
# Name: Country, dtype: object

# %%
Mexico_attacks = df.loc[(df['Country'] == "Mexico")]
Mexico_attacks
# Out:
#                         Date    Year          Type Country  \
# 11               29 Dec-2023  2023.0    Unprovoked  Mexico
# 16              14  Dec-2023  2023.0  Questionable  Mexico
# 17              14  Dec-2023  2023.0  Questionable  Mexico
# 20               02 Dec-2023  2023.0    Unprovoked  Mexico
# 30               23 Oct-2023  2023.0      Provoked  Mexico
# 101              17-Mar-2023  2023.0  Questionable  Mexico
# 115              05-Jan-2023  2023.0    Unprovoked  Mexico
# 204              12-Feb-2022  2022.0    Unprovoked  Mexico
# 219     Reported 06-Dec-2021  2021.0    Unprovoked  Mexico
# 440              23-Nov-2019  2019.0      Provoked  Mexico
# 444              11-Nov-2019  2019.0    Unprovoked  Mexico
# 489              06-Jul-2019  2019.0      Provoked  Mexico
# 523              21-Mar-2019  2019.0    Unprovoked  Mexico
# 541              18-Dec-2018  2018.0    Unprovoked  Mexico
# 612              04-Jun-2018  2018.0      Provoked  Mexico
# 734     Reported 07-Jul-2017  2017.0      Provoked  Mexico
# 756              05-May-2017  2017.0    Unprovoked  Mexico
# 784              07-Mar-2017  2017.0      Provoked  Mexico
# 820              13-Oct-2016  2016.0       Invalid  Mexico
# 840                 Sep-2016  2016.0       Invalid  Mexico
# 1059             10-Mar-2015  2015.0      Provoked  Mexico
# 1261             29-Jul-2013  2013.0    Unprovoked  Mexico
# 1294             24-Apr-2013  2013.0    Unprovoked  Mexico
# 1336             22-Nov-2012  2012.0    Unprovoked  Mexico
# 1405             29-May-2012  2012.0    Unprovoked  Mexico
# 1549             24-Mar-2011  2011.0    Unprovoked  Mexico
# 1551             21-Mar-2011  2011.0    Unprovoked  Mexico
# 1562    Reported 04-Feb-2011  2011.0      Provoked  Mexico
# 1564             31-Jan-2011  2011.0    Unprovoked  Mexico
# 1565             28-Jan-2011  2011.0      Provoked  Mexico
# 1569    Reported 12-Jan 2011  2011.0    Unprovoked  Mexico
# 1840             26-Jul-2008  2008.0    Unprovoked  Mexico
# 1870             24-May-2008  2008.0    Unprovoked  Mexico
# 1871             23-May-2008  2008.0    Unprovoked  Mexico
# 1877             28-Apr-2008  2008.0    Unprovoked  Mexico
# 1886             18-Apr-2008  2008.0       Invalid  Mexico
# 1913             Summer-2008  2008.0    Unprovoked  Mexico
# 1928           November 2011  2007.0       Invalid  Mexico
# 2191             20-Jun-2005  2005.0    Unprovoked  Mexico
# 2511             30-Sep-2001  2001.0    Unprovoked  Mexico
# 2550             06-Jul-2001  2001.0    Unprovoked  Mexico
# 2845             14-Aug-1997  1997.0       Invalid  Mexico
# 2846             14-Aug-1997  1997.0    Unprovoked  Mexico
# 3107             11-Jun-1993  1993.0    Unprovoked  Mexico
# 3170                May 1992  1992.0    Unprovoked  Mexico
# 3504             11-Sep-1984  1984.0      Provoked  Mexico
# 3677    Reported 22-Aug-1980  1980.0    Unprovoked  Mexico
# 3690                Apr-1980  1980.0    Unprovoked  Mexico
# 3781                Jan-1977  1977.0    Unprovoked  Mexico
# 3913                Dec-1973  1973.0    Unprovoked  Mexico
# 3920             09-Sep-1973  1973.0    Unprovoked  Mexico
# 3926             04-Apr-1973  1973.0    Unprovoked  Mexico
# 3930             27-Feb-1973  1973.0    Unprovoked  Mexico
# 3938             25-Dec-1972  1972.0    Unprovoked  Mexico
# 3990              6-Apr-1971  1971.0    Unprovoked  Mexico
# 4032             10-Jan-1970  1970.0    Unprovoked  Mexico
# 4095                Jul-1968  1968.0       Invalid  Mexico
# 4129    Reported 26-Oct-1967  1967.0    Unprovoked  Mexico
# 4162             06-Feb-1967  1967.0  Sea disaster  Mexico
# 4239             08-Sep-1965  1965.0    Unprovoked  Mexico
# 4243             26-Jul-1965  1965.0    Unprovoked  Mexico
# 4247             09-Jun-1965  1965.0    Unprovoked  Mexico
# 4250             29-May-1965  1965.0    Unprovoked  Mexico
# 4251             28-May-1965  1965.0    Unprovoked  Mexico
# 4254                May 1965  1965.0    Unprovoked  Mexico
# 4292             23-Aug-1964  1964.0    Unprovoked  Mexico
# 4412             25-Oct-1962  1962.0    Unprovoked  Mexico
# 4418             22-Sep-1962  1962.0    Unprovoked  Mexico
# 4497             14-Nov-1961  1961.0       Invalid  Mexico
# 4691                Sep-1959  1959.0    Unprovoked  Mexico
# 4715                Jul-1959  1959.0    Unprovoked  Mexico
# 4717             14-Jun-1959  1959.0    Unprovoked  Mexico
# 4765                Oct-1958  1958.0      Provoked  Mexico
# 4770             31-Aug-1958  1958.0          Boat  Mexico
# 4772    Reported 31-Jul-1958  1958.0    Unprovoked  Mexico
# 4983                    1954  1954.0    Unprovoked  Mexico
# 4998                Aug-1953  1953.0       Invalid  Mexico
# 4999             31-Jul-1953  1953.0    Unprovoked  Mexico
# 5074             22-May-1951  1951.0    Unprovoked  Mexico
# 5146             13-Apr-1949  1949.0    Unprovoked  Mexico
# 5301                Jul-1943  1943.0       Invalid  Mexico
# 5314             Summer 1943  1943.0    Unprovoked  Mexico
# 5630             06-Jan-1932  1932.0      Provoked  Mexico
# 5682             22-Jan-1930  1930.0    Watercraft  Mexico
# 5699             29-Jul-1929  1929.0    Unprovoked  Mexico
# 5805             25-Nov-1924  1924.0    Unprovoked  Mexico
# 5834             06-Jun-1923  1923.0    Watercraft  Mexico
# 5954    Reported 06-Jul-1915  1915.0    Unprovoked  Mexico
# 5955    Reported 06-Jul-1915  1915.0    Unprovoked  Mexico
# 6032    Reported 25-Jun-1910  1910.0    Unprovoked  Mexico
# 6050    Reported 26-Jun-1909  1909.0    Unprovoked  Mexico
# 6061    Reported 16-Dec-1908  1908.0    Unprovoked  Mexico
# 6088             20-Apr-1907  1907.0    Unprovoked  Mexico
# 6153             04-May-1903  1903.0    Unprovoked  Mexico
# 6201    Reported 11-Sep-1899  1899.0    Unprovoked  Mexico
# 6239             15-Oct-1897  1897.0       Invalid  Mexico
# 6292    Reported 15-Jun-1894  1894.0    Unprovoked  Mexico
# 6454    Reported 07-May-1880  1880.0       Invalid  Mexico
# 6517   Reported 18-Jun- 1874  1874.0    Unprovoked  Mexico
# 6562                Aug-1867  1867.0    Unprovoked  Mexico
# 6658    Reported 16-Jun-1851  1851.0    Unprovoked  Mexico
# 6678             12-Feb-1847  1847.0  Sea disaster  Mexico
# 6682             08-Dec-1846  1846.0  Sea disaster  Mexico
# 6686             04-Nov-1845  1845.0    Unprovoked  Mexico
# 6810           Ca 1588.04.00  1518.0    Unprovoked  Mexico
# 6811       Ca 1200-1500 A.D.  1500.0    Unprovoked  Mexico
#
#                        State                            Location  \
# 11                    Sonora  Tojahui Beach, Yavaros, Huatabampo
# 16                  Guerrero   Playa Quieta, Ixtapa, Zihuatanejo
# 17                  Guerrero   Playa Quieta, Ixtapa, Zihuatanejo
# 20                   Jalisco                San Patricio Melaque
# 30              Quintana Roo  Banco Chinchorro Biosphere Reserve
# 101             Quintana Roo                              Cancún
# 115       Gulf of California                          Tobari Bay
# 204                   Sonora                             Yavaros
# 219             Quintana Roo                            Mahahual
# 440                 Guerrero                     Off Barra Vieja
# 444                    Baja                        Magdalena Bay
# 489               Quinta Roo                       Cabo Catoche
# 523                 Guerrero                           Troncones
# 541                   Sonora        Southeast of Puerto Peñasco
# 612                   Colima                            La Ticla
# 734                  Tabasco        Sánchez Magallanes, Cárdenas
# 756      Baja California Sur           Los Arbolitos, Cabo Pulmo
# 784               Tamaulipas            Playa Baghdad, Matamoros
# 820                      NaN                    Guadalupe Island
# 840                      NaN                    Guadalupe Island
# 1059                 Sinaloa                            Mazlatan
# 1261            Quintana Roo                                 NaN
# 1294            Quintana Roo               Seagull Beach, Cancun
# 1336                 Sinaloa                        Nuevo Altata
# 1405                Guerrero           Boca de la Leña, La Unión
# 1549            Quintana Roo              Gaviotas Beach, Cancun
# 1551            Quintana Roo                                 NaN
# 1562                  Colima   Manzanillo, Revillagigedo Islands
# 1564            Quintana Roo                              Cancun
# 1565                  Colima               Revillagigedo Islands
# 1569            Quintana Roo                             Xcalak
# 1840          Cabo San Lucas                                 NaN
# 1870                  Guerro                         Playa Linda
# 1871                  Guerro                        Pantla Beach
# 1877                  Guerro                     Troncones Beach
# 1886            Quintana Roo              Delfines Beach, Cancun
# 1913         Baja California                   Playas de Tijuana
# 1928         Baja California                    Guadalupe Island
# 2191         Baja California                      San Luis beach
# 2511                Guerrero                              Ixtapa
# 2550         Baja California                            Ensenada
# 2845            Quintana Roo                 Santa Rosa, Cozumel
# 2846            Quintana Roo                 Santa Rosa, Cozumel
# 3107            Quintana Roo        Santa Rosa Shallows, Cozumel
# 3170  Mexico / Caribbean Sea                        Isla Mujeres
# 3504         Baja California                    Guadalupe Island
# 3677                     NaN                                 NaN
# 3690                 Sinaloa                            Mazatlán
# 3781                Guerrero     La Playa Hornos (near Acapulco)
# 3913                Guerrero                        Acapulco Bay
# 3920         Baja California                    Guadalupe Island
# 3926                Guerrero         Revolcadero Beach, Acapulco
# 3930                Guerrero         Revolcadero Beach, Acapulco
# 3938                Guerrero         Revolcadero Beach, Acapulco
# 3990                Guerrero          Copacabana Beach, Acapulco
# 4032                Guerrero                            Acapulco
# 4095         Baja California                                 NaN
# 4129                Veracruz                            Veracruz
# 4162                Veracruz                           Cabo Rojo
# 4239                Veracruz                 Playa Villa del Mar
# 4243                Veracruz                             Mocambo
# 4247                Veracruz                             Mocambo
# 4250                Veracruz                       Playa Mocambo
# 4251                Veracruz                       Playa Mocambo
# 4254                Veracruz                             Mocambo
# 4292                Guerrero                            Acapulco
# 4412                Veracruz       Villa del Mar Beach, Veracruz
# 4418                Veracruz       Villa del Mar Beach, Veracruz
# 4497               Guerrrero               Northwest of Acapulco
# 4691               Guerrrero                            Acapulco
# 4715            Quintana Roo                    Chinchorro Banks
# 4717                 Guyamas            San Pedro Nolasco Island
# 4765               Guerrrero                            Acapulco
# 4770         Baja California                            Ensenada
# 4772                Guerrero              Caleta Beach, Acapulco
# 4983         Baja California                                 NaN
# 4998                Guerrero                            Acapulco
# 4999                  Colima                          Manzanillo
# 5074                     NaN                                 NaN
# 5146              Tamaulipas              Miramar Beach, Tampico
# 5301                Veracruz       Villa del Mar Beach, Veracruz
# 5314                Veracruz       Villa del Mar Beach, Veracruz
# 5630         Baja California                       Descano Point
# 5682                Veracruz                  Panuco River Mouth
# 5699              Tamaulipas                             Tampico
# 5805              Tamaulipas                             Tampico
# 5834               Vera Cruz            Outside Vera Cruz Harbor
# 5954              Tamaulipas                             Tampico
# 5955                     NaN                     Santa Maria Bar
# 6032                     NaN                             LaBarra
# 6050                Guerrero                            Zacatula
# 6061            Quintana Roo                                 NaN
# 6088                  Oaxaca                         Salina Cruz
# 6153                Veracruz                       Coatzacoalcos
# 6201              Tamaulipas                             Tampico
# 6239               Vera Cruz                    Vera Cruz Harbor
# 6292         Bay of Campeche                                 NaN
# 6454                  Guerro                            Acapulco
# 6517               Veracruz               Tlacotalpan, Vera Cruz
# 6562               Veracruz                     Vera Cruz Harbor
# 6658                  Oaxaca                  Tehuantepec Harbor
# 6678                     NaN                                 NaN
# 6682                Veracruz                           Vera Cruz
# 6686               Vera Cruz                           Vera Cruz
# 6810                 Yucatan                             Cozumel
# 6811                     NaN                                 NaN
#
#                                                Activity  \
# 11                                          Free diving
# 16                                             Swimming
# 17                                             Swimming
# 20                                             Swimming
# 30                                              Fishing
# 101                                            Swimming
# 115                   Diving with  surface-supplied air
# 204                            Surface Supplied  Diving
# 219                                              Diving
# 440                                             Fishing
# 444                                          Snorkeling
# 489                                             Fishing
# 523                                            Swimming
# 541                                              Diving
# 612                                         Free diving
# 734                                             Fishing
# 756                                          Snorkeling
# 784                                             Fishing
# 820                                         Cage Diving
# 840                                         Cage Diving
# 1059                                            Fishing
# 1261                                             Wading
# 1294                                           Swimming
# 1336                                           Swimming
# 1405                         Free diving / spearfishing
# 1549                                           Swimming
# 1551                                           Swimming
# 1562               Shark fishing on the Ricardo Astorga
# 1564                                           Swimming
# 1565              Shark fishing on the Don Agustín-VI.
# 1569                            Attempting to fix motor
# 1840                                           Swimming
# 1870                                            Surfing
# 1871                                            Surfing
# 1877                                            Surfing
# 1886                                           Swimming
# 1913                                            Surfing
# 1928                                       Shark diving
# 2191                                            Surfing
# 2511                                       Body surfing
# 2550                                            Surfing
# 2845                                       SCUBA diving
# 2846                                       SCUBA diving
# 3107                                       Scuba diving
# 3170                             Scuba diving & filming
# 3504                                       Spearfishing
# 3677                                 Diving in tuna net
# 3690                                       Body surfing
# 3781                                           Swimming
# 3913             Swimming alongside yacht Mexico Fiesta
# 3920                          Free diving, Spearfishing
# 3926                                             Wading
# 3930                                           Swimming
# 3938                                       Body surfing
# 3990                                            Surfing
# 4032                                           Swimming
# 4095                                                NaN
# 4129                                           Swimming
# 4162  The shrimper Loless Maurine capsized in heavy ...
# 4239                                                NaN
# 4243                                            Bathing
# 4247                                           Swimming
# 4250                                           Swimming
# 4251                                           Swimming
# 4254                                           Swimming
# 4292              Floating on his back in an inner tube
# 4412                                             Wading
# 4418                                           Swimming
# 4497                                                NaN
# 4691                                                NaN
# 4715                                             Wading
# 4717                 Swimming ashore from capsized boat
# 4765                Slapped shark on tail as it swam by
# 4770               Boat stopped to repair electric pump
# 4772                                           Swimming
# 4983                                        Free diving
# 4998                                        Free diving
# 4999                                             Wading
# 5074                                        Free diving
# 5146                                            Bathing
# 5301                                           Swimming
# 5314                                           Swimming
# 5630                                            Fishing
# 5682               Fishing schooner Jose Luis foundered
# 5699                                           Swimming
# 5805  The Ward liner Esperanza stranded during a gal...
# 5834  Dismantling cable buoys of the cable ship All ...
# 5954                                            Fishing
# 5955                                             Wading
# 6032                                           Swimming
# 6050                                            Bathing
# 6061                 Swimming ashore from capsized boat
# 6088                                            Bathing
# 6153                                            Bathing
# 6201                                           Swimming
# 6239                                             Diving
# 6292            Fell from yardarm of British ship Rover
# 6454                                                NaN
# 6517                                            Bathing
# 6562              boat from the Austrian ship Elizabeth
# 6658                                            Bathing
# 6678                                 Wreck of the Tweed
# 6682                            Wreck of the USS Somers
# 6686                                            Bathing
# 6810                                            Swmming
# 6811                                                NaN
#
#                                                    Name  Sex           Age  \
# 11                                 Víctor Alejandro “N”    M            22
# 16                                Joseph Leopold Bynens    M            66
# 17                                    Valerie Haurowitz    F            52
# 20                     Maria Fernandez Martinez Jimenez    F            26
# 30                                                 male    M            59
# 101                                       Dillon Armijo    M            10
# 115                               Manuel Nieblas López     M            53
# 204                                     Victor Estrella    M            56
# 219                                     David Rodríguez    M            14
# 440                                                male    M           NaN
# 444                                   Kristoffer Nymann    M            23
# 489                                   Edgar Hernández,     M           NaN
# 523                                         Alex Wilton    M            32
# 541                             Nahum Verdugo Aguilera     M            35
# 612                                      Gustavo Ramos     M           NaN
# 734                             Andres Ovando Rodriguez    M            32
# 756                                       Andres Rozada    M            33
# 784                               Daniel Vázquez López     M           NaN
# 820                                           Ming Chan    M           NaN
# 840                                                 NaN  NaN           NaN
# 1059                                David Villegas Mora    M            36
# 1261                                       Bonnie Davis    F           NaN
# 1294                                   Isabella Carchia    F            34
# 1336                           Fernando Cardenas Garcia    M            32
# 1405                          Benigno Medina Navarrete     M            46
# 1549                                        Liuba Taran    F           NaN
# 1551                                  Andrew Masternak     M            46
# 1562                             Porfirio Lugo Camacho     M           NaN
# 1564                                       Nicole Moore    F            38
# 1565                     C. Pedro Luis Beltrán Camargo     M            25
# 1569                        Juan Miguel Infante Ramírez    M            37
# 1840                                      Ryan Seacrest    M            33
# 1870                                       Bruce Grimes    M            49
# 1871                           Osvaldo Mata Valdovinos     M            21
# 1877                                        Adrian Ruiz    M            24
# 1886                          Joram Galleros Villanueva    M            32
# 1913                                      Chase Edwards    M            26
# 1928                     Patrick Walsh & Paul Damgaard     M           NaN
# 2191                                      Frank Johnson    M           NaN
# 2511                                      Brian Lavelle    M            26
# 2550                                          Tim Fabel    M            42
# 2845                                       Mike Jonatis    M            28
# 2846                                         Mac Lupold    M            33
# 3107                                     Mary Eggemeyer    F            42
# 3170                                    Nick Caloyianis    M           NaN
# 3504                                       Harry Ingram    M           NaN
# 3677                                    Gerald Correria    M            22
# 3690                                      Kim Giambalvo    F            13
# 3781                                       Mexican male    M           NaN
# 3913                                      American male    M           20s
# 3920                                  Al Schneppershoff    M            37
# 3926                                 John P.R. Nicholls    M            45
# 3930                            Dr. Leo Ephraim Fischer  NaN            57
# 3938                                     Gerald Soukoff    M            17
# 3990                                         Jimmy Rowe    M            19
# 4032                                       Jack Kardell    M            22
# 4095                                     Robert Slatzer    M            43
# 4129                                          "a youth"  NaN           NaN
# 4162            Carlos Humberto Mendez & Esteban Robles    M           NaN
# 4239                              Miguel Salas Gonzalez    M            23
# 4243                      Hector Serfio Trillio Jimenez    M            25
# 4247   Father Miguel de Jesus Chavez, a Catholic priest    M            38
# 4250                                     Ignacio Millán    M           NaN
# 4251                               Fidel Garcia Montero    M           NaN
# 4254               Father Jose de Jesus Gomez, a priest    M            35
# 4292                                      Thad T. Moore    M            19
# 4412           Nicolas Jimenez Nunez, a Catholic priest    M            32
# 4418                                  Nestor Valenzuela    M            20
# 4497                                                NaN  NaN           NaN
# 4691                                       French woman    F  "middle-age"
# 4715                              Lobster fishermen x 2    M           NaN
# 4717                                Francisco R. Topete    M           NaN
# 4765                                               male    M           NaN
# 4770        16' cabin cruiser with 35 hp outboard motor  NaN           NaN
# 4772                                    Suzanne Dreufus    F           NaN
# 4983                                     Rosario Bianci    M           NaN
# 4998                                     Arthur R. Satz    M            19
# 4999                                 Ema Aquilera Prada    F            18
# 5074                                        Brian Lanse    M            16
# 5146                                               male    M           NaN
# 5301                            Manuel Zamora, a lawyer    M            68
# 5314                                     a U.S. citizen  NaN           NaN
# 5630                  Efrain Ybarra & Francisco Durazzo    M       36 & 23
# 5682                                                NaN  NaN           NaN
# 5699                            Crew member of Casanova    M           NaN
# 5805                                       Ofelia Rivas    F           NaN
# 5834     boat, occupants; Carl Sjoistrom & 2 other crew  NaN           NaN
# 5954                                    Captain Thaxton    M           NaN
# 5955                                      J.W. McDonald    M           NaN
# 6032                                          H. Gebler    M           NaN
# 6050                                         Rosa Lopez    F           NaN
# 6061                             Colonel Harry J. Earle    M           NaN
# 6088                                     Laurence Funda    M           NaN
# 6153                                              3 men    M           NaN
# 6201                                         Paul Guyot    M           NaN
# 6239                                  Alexander Cameron    M           NaN
# 6292                                             sailor    M           NaN
# 6454                                             A.H.C.    M           NaN
# 6517                          a servant of General Diaz    M           NaN
# 6562                                         14 crewmen    M           NaN
# 6658  John H. Gray & another member of the Tehuantep...    M           NaN
# 6678                                                NaN  NaN           NaN
# 6682                                                NaN    M           NaN
# 6686                                          a soldier    M           NaN
# 6810                                A cacique (a chief)    M           NaN
# 6811                                               male    M           NaN
#
#       ...                                           Species   \
# 11    ...                                        White shark
# 16    ...                      Shark involment not confirmed
# 17    ...                      Shark involment not confirmed
# 20    ...                                                NaN
# 30    ...                                                NaN
# 101   ...     Authorities report injury caused bya barracuda
# 115   ...                                                NaN
# 204   ...                                           3m shark
# 219   ...                                                NaN
# 440   ...                                                NaN
# 444   ...                                                NaN
# 489   ...                                                NaN
# 523   ...                                                NaN
# 541   ...                                        Tiger shark
# 612   ...                                    Tiger shark, 3m
# 734   ...                                Tiger shark, 100 kg
# 756   ...                                                NaN
# 784   ...                                                NaN
# 820   ...                                        White shark
# 840   ...                                            Invalid
# 1059  ...                                                NaN
# 1261  ...                                                NaN
# 1294  ...                                        Tiger shark
# 1336  ...                                        2.5 m shark
# 1405  ...                                     Bull shark, 3m
# 1549  ...                                         Bull shark
# 1551  ...                                                NaN
# 1562  ...                                                NaN
# 1564  ...                                           6' shark
# 1565  ...                                                NaN
# 1569  ...                                                NaN
# 1840  ...                                          2'  shark
# 1870  ...                                          3 m shark
# 1871  ...                                          2 m shark
# 1877  ...                                        Tiger shark
# 1886  ...  Reported by media as shark attack, but shark i...
# 1913  ...                        Possibly a hammerhead shark
# 1928  ...                                            Invalid
# 2191  ...                                                NaN
# 2511  ...                            Tiger shark, 1.8 m [6']
# 2550  ...                                                NaN
# 2845  ...  Shark involvement prior to death was not confi...
# 2846  ...                           Tiger shark, 5.2 m [17']
# 3107  ...                                                NaN
# 3170  ...                                                NaN
# 3504  ...                          4.5 m to 5.5m white shark
# 3677  ...                                                NaN
# 3690  ...                                        Tiger shark
# 3781  ...                                                NaN
# 3913  ...                                                NaN
# 3920  ...                                        White shark
# 3926  ...                                                NaN
# 3930  ...                                                NaN
# 3938  ...                                                NaN
# 3990  ...                                                NaN
# 4032  ...                                                NaN
# 4095  ...                                  Not authenticated
# 4129  ...                                                NaN
# 4162  ...                                                NaN
# 4239  ...                              300-kg [662-lb] shark
# 4243  ...                                                NaN
# 4247  ...                                                NaN
# 4250  ...                                                NaN
# 4251  ...                                                NaN
# 4254  ...                                                NaN
# 4292  ...                      1.8 to 2.4 m [6' to 8'] shark
# 4412  ...                                   2.7 m [9'] shark
# 4418  ...                                                NaN
# 4497  ...  Shark involvement prior to death was not confi...
# 4691  ...                                                NaN
# 4715  ...                                                NaN
# 4717  ...                                                NaN
# 4765  ...                                                NaN
# 4770  ...                     Hammerhead shark, 5.2 m [17']
# 4772  ...                                                NaN
# 4983  ...                                                NaN
# 4998  ...                                            Invalid
# 4999  ...                                                NaN
# 5074  ...                                                NaN
# 5146  ...                                                NaN
# 5301  ...                                            Invalid
# 5314  ...                                                NaN
# 5630  ...                                                NaN
# 5682  ...                                                NaN
# 5699  ...                                                NaN
# 5805  ...                                        1.8 m shark
# 5834  ...                                                NaN
# 5954  ...                                                NaN
# 5955  ...                                                NaN
# 6032  ...                                                NaN
# 6050  ...                                                NaN
# 6061  ...                                                NaN
# 6088  ...                                                NaN
# 6153  ...                                                NaN
# 6201  ...                                                NaN
# 6239  ...                                       Questionable
# 6292  ...                                          20' shark
# 6454  ...       Shark involvement prior to death unconfirmed
# 6517  ...                                                NaN
# 6562  ...                                                NaN
# 6658  ...                                                NaN
# 6678  ...                                                NaN
# 6682  ...                                                NaN
# 6686  ...                                                NaN
# 6810  ...                                                NaN
# 6811  ...                                                NaN
#
#                                                  Source  \
# 11                               EuroESEuro, 12/31/2023
# 16                                  EL Pais, 12/15/2023
# 17                                  EL Pais, 12/15/2023
# 20                           News Channel 21, 12/3.2023
# 30                             TYT Newsroom. 10/26/2023
# 101                                  Denver7, 3/29/2023
# 115                             El imparcial., 1/5/2023
# 204                     K. McMurray, TrackingSharks.com
# 219                       Riviera Maya Times, 12/6/2021
# 440                  Kevin McMurray, TrackingSharks.com
# 444                      K.McMurray, TrackingSharks.com
# 489                     K. McMurray, TrackingSharks.com
# 523                      K.McMurray, TrackingSharks.com
# 541                     K. McMurray, TrackingSharks.com
# 612                                           A .Kipper
# 734                               Tabasco Hoy, 7/7/2017
# 756                                           J. Rozada
# 784        K. McMurray, Tracking Sharks.com, 12/21/2018
# 820                                             YouTube
# 840                                           K. Yonker
# 1059                                 Noreste, 3/10/2015
# 1261                A. Brenneka, Shark Attack Survivors
# 1294  I. Carchia; A. Brenneka, Shark Attack Survivor...
# 1336                           El Universal, 11/22/2012
# 1405                       El Sol ee Morelia, 5/30/2012
# 1549                          Canadian press, 3/25/2011
# 1551                         Mississauga.net, 3/29/2011
# 1562                          AngelGuardianMX, 2/4/2011
# 1564                     El Diario de Yucatan, 2/1/2011
# 1565                            Sun Sentinel, 1/30/2011
# 1569                                 Sharksurvivors.com
# 1840                                Fox News, 7/28/2008
# 1870                                   Associated Press
# 1871                                            Reuters
# 1877                                       Surfline.com
# 1886                                        C.Johansson
# 1913                         San Diego Reader, 1/7/2009
# 1928                                         Today Show
# 2191  http://www.signonsandiego.com/news/mexico/2005...
# 2511                                         T. Carlson
# 2550                                               KGTV
# 2845  Charlotte Observer, 8/22/2997, p.7C & 8C; York...
# 2846  Charlotte Observer, 8/22/2997, p.7C & 8C; York...
# 3107                    Dallas Morning News, 6//15/1993
# 3170                                    T. Allen, p.238
# 3504                                         R. Collier
# 3677                Valley Independent, 8/22/1980, p.16
# 3690                   K. Giambalvo-Sprague; R. Collier
# 3781                                 A.Resciniti, p.107
# 3913                            A.Resciniti, pp.107-108
# 3920  Washington Post, 9/12/1973; J. McCosker & R.N....
# 3926                                 A.Resciniti, p.108
# 3930    Reno Gazette, 4/8/1973; A.Resciniti, pp.108-109
# 3938         The Gleaner, 1/3/1973; A. Resciniti, p.109
# 3990                                 A.Resciniti, p.109
# 4032                                A. Resciniti, p.110
# 4095                      H.D.Baldridge, SAF Case #1613
# 4129                        Chicago Tribune, 10/27/1967
# 4162                      Brownsville Herald, 1/28/1968
# 4239           F. Piskur; press clipping dated 9/9/1965
# 4243         Latin American Times (New York), 8/3/1965
# 4247  J. Carranza (This is apparently a different ca...
# 4250                   The News (Mexico City) 6/1/1965
# 4251                    The News (Mexico City) 6/1/1965
# 4254                   The News (Mexico City) 6/12/1965
# 4292                                         T.T. Moore
# 4412                                        C.G. Robles
# 4418                                        C.G. Robles
# 4497  Sydney Daily Telegraph, 11/19/1961; SAF Case #...
# 4691  A. R. Satz;  P. Gilbert, L. Schultz & S. Sprin...
# 4715                                        C.G. Robles
# 4717                            Miami Herald, 6/15/1959
# 4765  Washington Evening Star, 6/17/1959; V.M. Coppl...
# 4770                             G.A. Llano, pp.176-177
# 4772  Miami Herald, 8/2/1958 reported this was the s...
# 4983  V.M. Coppleson, p.262; V.M. Coppleson (1962), ...
# 4998                H.D. Baldridge (1994) SAF Case #679
# 4999        V.M. Coppleson (1958), p.262; J.M. Alatorre
# 5074               H.D.Baldridge (1994), SAF Case #1482
# 5146                 New York Herald Tribune, 4/15/1949
# 5301                       C.G. Robles; SAF Case #1327
# 5314                                        C.G. Robles
# 5630                       NY Herald Tribune, 1/8/1933
# 5682                    Reno Evening Gazette, 2/14/1930
# 5699                       V.M. Coppleson (1958), p.262
# 5805                      Indianapolis Star, 12/15/1924
# 5834                NY Herald Tribune, undated clipping
# 5954                          Oakland Tribune, 7/6/1915
# 5955                          Oakland Tribune, 7/6/1915
# 6032                 Indiana Evening Gazette, 9/25/1910
# 6050                       Adams County News, 6/26/1909
# 6061  Lowell Sun, 12/16/1908; V.M. Coppleson (1962),...
# 6088                 Los Angles Times, 8/7/1907, p.II11
# 6153                          Chicago Tribune, 5/5/1903
# 6201                     Bryan Morning Eagle, 9/12/1899
# 6239                               NY Times, 11/11/1897
# 6292                           Warren Ledger, 6/15/1894
# 6454                       Dover Weekly Argus, 5/7/1880
# 6517                      The Times-Picayune, 6/18/1874
# 6562                        Washington Star, 12/12/1891
# 6658      Daily Free Democrat (Milwaukee, WI) 6/16/1851
# 6678                            The Guardian, 3/26/1858
# 6682           Report of the loss of the Somers, J.H.W.
# 6686                       New York Tribune, 12/15/1845
# 6810                                     C. Moore, GSAF
# 6811                                          J. Castro
#
#                                      pdf  \
# 11                                   NaN
# 16                                   NaN
# 17                                   NaN
# 20                                   NaN
# 30                                   NaN
# 101                                  NaN
# 115                                  NaN
# 204              2022.02.12-Estrella.pdf
# 219           2021.12.06.R-Rodriguez.pdf
# 440            2019.11.23.R-Acapulco.pdf
# 444                2019.11.11-Nymann.pdf
# 489             2019.07.06-Hernandez.pdf
# 523                2019.03.21-Winton.pdf
# 541              2018.12.18-Aguilera.pdf
# 612                 2018.06.04-Ramos.pdf
# 734           2017.07.07.R-Rodriguez.pdf
# 756                2017.05.06-Rozada.pdf
# 784                 2017.03.07-Lopez.pdf
# 820              2016.10.13.R-Breach.pdf
# 840                2016.09.00-Breach.pdf
# 1059                 2015.03.10-Mora.pdf
# 1261              2013.07.29.b-Davis.pdf
# 1294              2013.04.24-Carchia.pdf
# 1336               2012.11.22-Garcia.pdf
# 1405           2012.05.29-Navarrette.pdf
# 1549                2011.03.24-Taran.pdf
# 1551          2011.03.21.b-Masternak.pdf
# 1562            2011.02.04.R-Camacho.pdf
# 1564                2011.01.31-Moore.pdf
# 1565              2011.01.28-Camargo.pdf
# 1569            2011.01.12.R-Infante.pdf
# 1840           2008.07.26.b-Seacrest.pdf
# 1870             2008.05.24.a-Grimes.pdf
# 1871                 2008.05.23-Mata.pdf
# 1877               2008.04.28.b-Ruiz.pdf
# 1886           2008.04.18-Villanueva.pdf
# 1913            2008.00.00.a-Edwards.pdf
# 1928                 2007.11.00-cage.pdf
# 2191              2005.06.21-Johnson.pdf
# 2511            2001.09.30.b-Lavelle.pdf
# 2550              2001.07.06.b-Fabel.pdf
# 2845           1997.08.14.b-Joniatis.pdf
# 2846            1997.08.14.a- Lupold.pdf
# 3107          1993.06.11.a-Eggemeyer.pdf
# 3170           1992.05.00-Caloyianis.pdf
# 3504               1984.09.11-Ingram.pdf
# 3677           1980.08.22.R-Correria.pdf
# 3690    1980.04.00-Giambalvo-Sprague.pdf
# 3781          1977.01.00-MexicanMale.pdf
# 3913        1973.12.00-MexicanFiesta.pdf
# 3920       1973.09.09-Schneppershoff.pdf
# 3926              1973.04.04-Nicolls.pdf
# 3930              1973.02.27-Ephraim.pdf
# 3938              1972.12.25-Sockoff.pdf
# 3990                 1971.04.06-Rowe.pdf
# 4032              1970.01.10-Kardell.pdf
# 4095           1968.07.00-NV-Slatzer.pdf
# 4129           1967.10.26.R-Veracruz.pdf
# 4162        1967.02.06-Mendez-Robles.pdf
# 4239             1965.09.08-Gonzalez.pdf
# 4243              1965.07.26-Jimenez.pdf
# 4247               1965.06.09-Chavez.pdf
# 4250               1965.05.29-Millan.pdf
# 4251              1965.05.28-Montero.pdf
# 4254              1965.05.00.a-Gomez.pdf
# 4292                1964.08.23-Moore.pdf
# 4412                1962.10.25-Nunez.pdf
# 4418           1962.09.22-Valenzuela.pdf
# 4497            1961.11.14-Hurricane.pdf
# 4691         1959.09.00-French-woman.pdf
# 4715  1959.07.00.a-Lobster-fishermen.pdf
# 4717             1959.06.14.b-Topete.pdf
# 4765           1958.10.00.b-Acapulco.pdf
# 4770          1958.08.31-NV-Ensenada.pdf
# 4772              1958.07.31-Dreufus.pdf
# 4983             1954.00.00.c-Bianci.pdf
# 4998              1953.08.00-NV-Satz.pdf
# 4999                1953.07.31-Prada.pdf
# 5074             1951.05.22-NV-Lanse.pdf
# 5146              1949.04.13-Miramar.pdf
# 5301             1943.07.00.a-Zamora.pdf
# 5314        1943.00.00.f-NV-Veracruz.pdf
# 5630        1932.01.06-BajaFishermen.pdf
# 5682      1930.01.22-FishingSchooner.pdf
# 5699             1929.07.29-Casanova.pdf
# 5805                1924.11.25-Rivas.pdf
# 5834           1923.06.06-AllAmerica.pdf
# 5954          1915.07.06.b.R-Thaxton.pdf
# 5955         1915.07.06.a.R-McDonald.pdf
# 6032             1910.06.25.R-Gebler.pdf
# 6050            1909.06.26.a.R-Lopez.pdf
# 6061                1908.12.16-Earle.pdf
# 6088                1907.04.20-Funda.pdf
# 6153             1903.05.04-Mexicox3.pdf
# 6201                  1899.09.11.R-Guyot
# 6239              1897.10.15-Cameron.pdf
# 6292            1894.06.15.a-R-Rover.pdf
# 6454                1880.05.07.R-AHC.pdf
# 6517        1874.06.18.R-DiazServant.pdf
# 6562        1867.08.00-ElizabethCrew.pdf
# 6658           1851.06.16.R-JohnGray.pdf
# 6678                1847.02.12-Tweed.pdf
# 6682               1846.12.08-Somers.pdf
# 6686             1845.11.04-VeraCruz.pdf
# 6810              1518.04.00.R.chief.pdf
# 6811                   1200AD-Mexico.pdf
#
#                                            href formula  \
# 11                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 20                                                  NaN
# 30                                                  NaN
# 101                                                 NaN
# 115                                                 NaN
# 204   http://sharkattackfile.net/spreadsheets/pdf_di...
# 219   http://sharkattackfile.net/spreadsheets/pdf_di...
# 440   http://sharkattackfile.net/spreadsheets/pdf_di...
# 444   http://sharkattackfile.net/spreadsheets/pdf_di...
# 489   http://sharkattackfile.net/spreadsheets/pdf_di...
# 523   http://sharkattackfile.net/spreadsheets/pdf_di...
# 541   http://sharkattackfile.net/spreadsheets/pdf_di...
# 612   http://sharkattackfile.net/spreadsheets/pdf_di...
# 734   http://sharkattackfile.net/spreadsheets/pdf_di...
# 756   http://sharkattackfile.net/spreadsheets/pdf_di...
# 784   http://sharkattackfile.net/spreadsheets/pdf_di...
# 820   http://sharkattackfile.net/spreadsheets/pdf_di...
# 840   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1059  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1261  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1294  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1336  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1405  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...
# 5699  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5805  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5834  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5954  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5955  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6032  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6050  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6061  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6088  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6153  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6201  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6239  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6292  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6454  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6517  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6562  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6658  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6678  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6682  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6686  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6810                             1518.04.00.R-chief.pdf
# 6811                                  1200AD-Mexico.pdf
#
#                                                    href     Case Number  \
# 11                                                  NaN             NaN
# 16                                                  NaN             NaN
# 17                                                  NaN             NaN
# 20                                                  NaN             NaN
# 30                                                  NaN             NaN
# 101                                                 NaN             NaN
# 115                                                 NaN             NaN
# 204   http://sharkattackfile.net/spreadsheets/pdf_di...      2022.02.12
# 219   http://sharkattackfile.net/spreadsheets/pdf_di...    2021.12.06.r
# 440   http://sharkattackfile.net/spreadsheets/pdf_di...    2019.11.23.R
# 444   http://sharkattackfile.net/spreadsheets/pdf_di...      2019.11.11
# 489   http://sharkattackfile.net/spreadsheets/pdf_di...      2019.07.06
# 523   http://sharkattackfile.net/spreadsheets/pdf_di...      2019.03.21
# 541   http://sharkattackfile.net/spreadsheets/pdf_di...      2018.12.18
# 612   http://sharkattackfile.net/spreadsheets/pdf_di...      2018.06.04
# 734   http://sharkattackfile.net/spreadsheets/pdf_di...    2017.07.07.R
# 756   http://sharkattackfile.net/spreadsheets/pdf_di...      2017.06.06
# 784   http://sharkattackfile.net/spreadsheets/pdf_di...      2017.03.07
# 820   http://sharkattackfile.net/spreadsheets/pdf_di...    2016.10.13.R
# 840   http://sharkattackfile.net/spreadsheets/pdf_di...      2016.09.00
# 1059  http://sharkattackfile.net/spreadsheets/pdf_di...      2015.03.10
# 1261  http://sharkattackfile.net/spreadsheets/pdf_di...    2013.07.29.b
# 1294  http://sharkattackfile.net/spreadsheets/pdf_di...      2013.04.24
# 1336  http://sharkattackfile.net/spreadsheets/pdf_di...      2012.11.22
# 1405  http://sharkattackfile.net/spreadsheets/pdf_di...      2012.05.29
# 1549  http://sharkattackfile.net/spreadsheets/pdf_di...      2011.03.24
# 1551  http://sharkattackfile.net/spreadsheets/pdf_di...    2011.03.21.b
# 1562  http://sharkattackfile.net/spreadsheets/pdf_di...    2011.02.04.R
# 1564  http://sharkattackfile.net/spreadsheets/pdf_di...      2011.01.31
# 1565  http://sharkattackfile.net/spreadsheets/pdf_di...      2011.01.28
# 1569  http://sharkattackfile.net/spreadsheets/pdf_di...    2011.01.12.R
# 1840  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.07.26.b
# 1870  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.05.24.a
# 1871  http://sharkattackfile.net/spreadsheets/pdf_di...      2008.05.23
# 1877  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.04.28.b
# 1886  http://sharkattackfile.net/spreadsheets/pdf_di...      2008.04.18
# 1913  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.00.00.a
# 1928  http://sharkattackfile.net/spreadsheets/pdf_di...      2007.11.00
# 2191  http://sharkattackfile.net/spreadsheets/pdf_di...      2005.06.21
# 2511  http://sharkattackfile.net/spreadsheets/pdf_di...    2001.09.30.b
# 2550  http://sharkattackfile.net/spreadsheets/pdf_di...    2001.07.06.b
# 2845  http://sharkattackfile.net/spreadsheets/pdf_di...    1997.08.14.b
# 2846  http://sharkattackfile.net/spreadsheets/pdf_di...    1997.08.14.a
# 3107  http://sharkattackfile.net/spreadsheets/pdf_di...    1993.06.11.a
# 3170  http://sharkattackfile.net/spreadsheets/pdf_di...      1992.05.00
# 3504  http://sharkattackfile.net/spreadsheets/pdf_di...      1984.09.11
# 3677  http://sharkattackfile.net/spreadsheets/pdf_di...    1980.08.22.R
# 3690  http://sharkattackfile.net/spreadsheets/pdf_di...      1980.04.00
# 3781  http://sharkattackfile.net/spreadsheets/pdf_di...      1977.01.00
# 3913  http://sharkattackfile.net/spreadsheets/pdf_di...      1973.12.00
# 3920  http://sharkattackfile.net/spreadsheets/pdf_di...      1973.09.09
# 3926  http://sharkattackfile.net/spreadsheets/pdf_di...      1973.04.04
# 3930  http://sharkattackfile.net/spreadsheets/pdf_di...      1973.02.27
# 3938  http://sharkattackfile.net/spreadsheets/pdf_di...      1972.12.25
# 3990  http://sharkattackfile.net/spreadsheets/pdf_di...      1971.04.06
# 4032  http://sharkattackfile.net/spreadsheets/pdf_di...      1970.01.10
# 4095  http://sharkattackfile.net/spreadsheets/pdf_di...      1968.07.00
# 4129  http://sharkattackfile.net/spreadsheets/pdf_di...    1967.10.26.R
# 4162  http://sharkattackfile.net/spreadsheets/pdf_di...      1967.02.06
# 4239  http://sharkattackfile.net/spreadsheets/pdf_di...      1965.09.08
# 4243  http://sharkattackfile.net/spreadsheets/pdf_di...      1965.07.26
# 4247  http://sharkattackfile.net/spreadsheets/pdf_di...      1965.06.09
# 4250  http://sharkattackfile.net/spreadsheets/pdf_di...      1965.05.29
# 4251  http://sharkattackfile.net/spreadsheets/pdf_di...      1965.05.28
# 4254  http://sharkattackfile.net/spreadsheets/pdf_di...    1965.05.00.a
# 4292  http://sharkattackfile.net/spreadsheets/pdf_di...      1964.08.23
# 4412  http://sharkattackfile.net/spreadsheets/pdf_di...      1962.10.25
# 4418  http://sharkattackfile.net/spreadsheets/pdf_di...      1962.09.22
# 4497  http://sharkattackfile.net/spreadsheets/pdf_di...      1961.11.14
# 4691  http://sharkattackfile.net/spreadsheets/pdf_di...      1959.09.00
# 4715  http://sharkattackfile.net/spreadsheets/pdf_di...    1959.07.00.a
# 4717  http://sharkattackfile.net/spreadsheets/pdf_di...    1959.06.14.b
# 4765  http://sharkattackfile.net/spreadsheets/pdf_di...    1958.10.00.b
# 4770  http://sharkattackfile.net/spreadsheets/pdf_di...      1958.08.31
# 4772  http://sharkattackfile.net/spreadsheets/pdf_di...    1958.07.31.R
# 4983  http://sharkattackfile.net/spreadsheets/pdf_di...    1954.00.00.c
# 4998  http://sharkattackfile.net/spreadsheets/pdf_di...      1953.08.00
# 4999  http://sharkattackfile.net/spreadsheets/pdf_di...      1953.07.31
# 5074  http://sharkattackfile.net/spreadsheets/pdf_di...      1951.05.22
# 5146  http://sharkattackfile.net/spreadsheets/pdf_di...      1949.04.13
# 5301  http://sharkattackfile.net/spreadsheets/pdf_di...    1943.07.00.a
# 5314  http://sharkattackfile.net/spreadsheets/pdf_di...    1943.00.00.f
# 5630  http://sharkattackfile.net/spreadsheets/pdf_di...      1932.01.06
# 5682  http://sharkattackfile.net/spreadsheets/pdf_di...      1930.01.22
# 5699  http://sharkattackfile.net/spreadsheets/pdf_di...      1929.07.29
# 5805  http://sharkattackfile.net/spreadsheets/pdf_di...      1924.11.25
# 5834  http://sharkattackfile.net/spreadsheets/pdf_di...      1923.06.06
# 5954  http://sharkattackfile.net/spreadsheets/pdf_di...  1915.07.06.a.R
# 5955  http://sharkattackfile.net/spreadsheets/pdf_di...  1915.07.06.a.R
# 6032  http://sharkattackfile.net/spreadsheets/pdf_di...    1910.06.25.R
# 6050  http://sharkattackfile.net/spreadsheets/pdf_di...  1909.06.26.a.R
# 6061  http://sharkattackfile.net/spreadsheets/pdf_di...    1908.12.16.R
# 6088  http://sharkattackfile.net/spreadsheets/pdf_di...      1907.04.20
# 6153  http://sharkattackfile.net/spreadsheets/pdf_di...      1903.05.04
# 6201  http://sharkattackfile.net/spreadsheets/pdf_di...    1899.09.11.R
# 6239  http://sharkattackfile.net/spreadsheets/pdf_di...      1897.10.15
# 6292  http://sharkattackfile.net/spreadsheets/pdf_di...  1894.06.15.a.R
# 6454  http://sharkattackfile.net/spreadsheets/pdf_di...    1880.05.07.R
# 6517  http://sharkattackfile.net/spreadsheets/pdf_di...    1874.06.18.R
# 6562  http://sharkattackfile.net/spreadsheets/pdf_di...      1867.08.00
# 6658  http://sharkattackfile.net/spreadsheets/pdf_di...    1851.06.16.R
# 6678  http://sharkattackfile.net/spreadsheets/pdf_di...      1847.02.12
# 6682  http://sharkattackfile.net/spreadsheets/pdf_di...      1846.12.08
# 6686  http://sharkattackfile.net/spreadsheets/pdf_di...      1845.11.04
# 6810                             1518.04.00.R-chief.pdf    1518.04.00.R
# 6811                                  1200AD-Mexico.pdf      1200.00.00
#
#        Case Number.1 original order Unnamed: 21 Unnamed: 22
# 11               NaN            NaN         NaN         NaN
# 16               NaN            NaN         NaN         NaN
# 17               NaN            NaN         NaN         NaN
# 20               NaN            NaN         NaN         NaN
# 30               NaN            NaN         NaN         NaN
# 101              NaN            NaN         NaN         NaN
# 115              NaN            NaN         NaN         NaN
# 204       2022.02.12         6738.0         NaN         NaN
# 219     2021.12.06.R         6722.0         NaN         NaN
# 440     2019.11.23.R         6502.0         NaN         NaN
# 444       2019.11.11         6498.0         NaN         NaN
# 489       2019.07.06         6453.0         NaN         NaN
# 523       2019.03.21         6419.0         NaN         NaN
# 541       2018.12.18         6401.0         NaN         NaN
# 612       2018.06.04         6330.0         NaN         NaN
# 734     2017.07.07.R         6209.0         NaN         NaN
# 756       2017.05.06         6187.0         NaN         NaN
# 784       2017.03.07         6159.0         NaN         NaN
# 820     2016.10.13.R         6123.0         NaN         NaN
# 840       2016.09.00         6103.0         NaN         NaN
# 1059      2015.03.10         5884.0         NaN         NaN
# 1261    2013.07.29.b         5681.0         NaN         NaN
# 1294      2013.04.24         5648.0         NaN         NaN
# 1336      2012.11.22         5606.0         NaN         NaN
# 1405      2012.05.29         5537.0         NaN         NaN
# 1549      2011.03.24         5393.0         NaN         NaN
# 1551    2011.03.21.b         5391.0         NaN         NaN
# 1562    2011.02.04.R         5380.0         NaN         NaN
# 1564      2011.01.31         5378.0         NaN         NaN
# 1565      2011.01.28         5377.0         NaN         NaN
# 1569    2011.01.12.R         5373.0         NaN         NaN
# 1840    2008.07.26.b         5102.0         NaN         NaN
# 1870    2008.05.24.a         5072.0         NaN         NaN
# 1871      2008.05.23         5071.0         NaN         NaN
# 1877    2008.04.28.b         5065.0         NaN         NaN
# 1886      2008.04.18         5056.0         NaN         NaN
# 1913    2008.00.00.a         5029.0         NaN         NaN
# 1928      2007.11.00         5014.0         NaN         NaN
# 2191      2005.06.21         4751.0         NaN         NaN
# 2511    2001.09.30.b         4431.0         NaN         NaN
# 2550    2001.07.06.b         4392.0         NaN         NaN
# 2845    1997.08.14.b         4097.0         NaN         NaN
# 2846    1997.08.14.a         4096.0         NaN         NaN
# 3107    1993.06.11.a         3835.0         NaN         NaN
# 3170      1992.05.00         3772.0         NaN         NaN
# 3504      1984.09.11         3438.0         NaN         NaN
# 3677    1980.08.22.R         3265.0         NaN         NaN
# 3690      1980.04.00         3252.0         NaN         NaN
# 3781      1977.01.00         3161.0         NaN         NaN
# 3913      1973.12.00         3029.0         NaN         NaN
# 3920      1973.09.09         3022.0         NaN         NaN
# 3926      1973.04.04         3016.0         NaN         NaN
# 3930      1973.02.27         3012.0         NaN         NaN
# 3938      1972.12.25         3004.0         NaN         NaN
# 3990      1971.04.06         2952.0         NaN         NaN
# 4032      1970.01.10         2910.0         NaN         NaN
# 4095      1968.07.00         2847.0         NaN         NaN
# 4129    1967.10.26.R         2813.0         NaN         NaN
# 4162      1967.02.06         2780.0         NaN         NaN
# 4239      1965.09.08         2703.0         NaN         NaN
# 4243      1965.07.26         2699.0         NaN         NaN
# 4247      1965.06.09         2695.0         NaN         NaN
# 4250      1965.05.29         2692.0         NaN         NaN
# 4251      1965.05.28         2691.0         NaN         NaN
# 4254    1965.05.00.a         2688.0         NaN         NaN
# 4292      1964.08.23         2650.0         NaN         NaN
# 4412      1962.10.25         2530.0         NaN         NaN
# 4418      1962.09.22         2524.0         NaN         NaN
# 4497      1961.11.14         2445.0         NaN         NaN
# 4691      1959.09.00         2251.0         NaN         NaN
# 4715    1959.07.00.a         2227.0         NaN         NaN
# 4717    1959.06.14.b         2225.0         NaN         NaN
# 4765    1958.10.00.b         2177.0         NaN         NaN
# 4770      1958.08.31         2172.0         NaN         NaN
# 4772    1958.07.31.R         2170.0         NaN         NaN
# 4983    1954.00.00.c         1959.0         NaN         NaN
# 4998      1953.08.00         1944.0         NaN         NaN
# 4999      1953.07.31         1943.0         NaN         NaN
# 5074      1951.05.22         1868.0         NaN         NaN
# 5146      1949.04.13         1796.0         NaN         NaN
# 5301    1943.07.00.a         1641.0         NaN         NaN
# 5314    1943.00.00.f         1628.0         NaN         NaN
# 5630      1932.01.06         1313.0         NaN         NaN
# 5682      1930.01.22         1261.0         NaN         NaN
# 5699      1929.07.29         1244.0         NaN         NaN
# 5805      1924.11.25         1138.0         NaN         NaN
# 5834      1923.06.06         1109.0         NaN         NaN
# 5954  1915.07.06.a.R          989.0         NaN         NaN
# 5955  1915.07.06.a.R          988.0         NaN         NaN
# 6032    1910.06.25.R          911.0         NaN         NaN
# 6050  1909.06.26.a.R          893.0         NaN         NaN
# 6061    1908.12.16.R          882.0         NaN         NaN
# 6088      1907.04.20          855.0         NaN         NaN
# 6153      1903.05.04          790.0         NaN         NaN
# 6201    1899.09.11.R          742.0         NaN         NaN
# 6239      1897.10.15          704.0         NaN         NaN
# 6292  1894.06.15.a.R          651.0         NaN         NaN
# 6454    1880.05.07.R          489.0         NaN         NaN
# 6517    1876.06.18.R          426.0         NaN         NaN
# 6562      1867.08.00          381.0         NaN         NaN
# 6658    1851.06.16.R          285.0         NaN         NaN
# 6678      1847.02.12          265.0         NaN         NaN
# 6682      1846.12.08          261.0         NaN         NaN
# 6686      1845.11.04          257.0         NaN         NaN
# 6810    1518.04.00.R          135.0         NaN         NaN
# 6811      1200.00.00          134.0         NaN         NaN
#
# [106 rows x 23 columns]

# %%
specific_countries = ["Mexico", "Portugal", "South Africa", "Australia"]
df_filtered = df[df["Country"].isin(specific_countries)]
df_filtered
# Out:
#              Date    Year        Type    Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked  Australia         Queensland
# 3     25 Feb-2024  2024.0  Unprovoked  Australia  Western Australia
# 6     29 Jan-2024  2024.0  Unprovoked  Australia   New  South Wales
# 8     09-Jan-2024  2024.0  Unprovoked  Australia    South Australia
# 11    29 Dec-2023  2023.0  Unprovoked     Mexico             Sonora
# ...           ...     ...         ...        ...                ...
# 6936  Before 1906     0.0  Unprovoked  Australia                NaN
# 6937  Before 1906     0.0  Unprovoked  Australia                NaN
# 6938  Before 1906     0.0  Unprovoked  Australia    New South Wales
# 6939  Before 1903     0.0  Unprovoked  Australia  Western Australia
# 6940  Before 1903     0.0  Unprovoked  Australia  Western Australia
#
#                                 Location      Activity                  Name  \
# 0                          Bargara Beach      Swimming        Brooklyn Sauer
# 3             Sandlnd Island, Jurian Bay           NaN                female
# 6           Elizabeth Bay, Sydney Harbor      Swimming        Lauren O'Neill
# 8                Walkers Beach, Elliston       Surfing          Murray Adams
# 11    Tojahui Beach, Yavaros, Huatabampo   Free diving  Víctor Alejandro “N”
# ...                                  ...           ...                   ...
# 6936                                 NaN       Fishing             fisherman
# 6937                                 NaN       Fishing             fisherman
# 6938                                          Swimming              Arab boy
# 6939                         Roebuck Bay        Diving                  male
# 6940                                 NaN  Pearl diving                 Ahmun
#
#      Sex  Age  ...                                           Species   \
# 0      F   13  ...                                        Tiger shark
# 3      F   46  ...                                        Tiger shark
# 6      F   29  ...                                         Bull shark
# 8      M   64  ...                                        White shark
# 11     M   22  ...                                        White shark
# ...   ..  ...  ...                                                ...
# 6936   M  NaN  ...                                       Blue pointer
# 6937   M  NaN  ...                                      Blue pointers
# 6938   M  NaN  ...  Said to involve a grey nurse shark that leapt ...
# 6939   M  NaN  ...                                                NaN
# 6940   M  NaN  ...                                                NaN
#
#                                                  Source  \
# 0                                 Yahoo News, 3/15/2024
# 3                                   WA Today, 2/26/2024
# 6                                 Nine News, 12/31/2024
# 8                                       A. Currie, GSAF
# 11                               EuroESEuro, 12/31/2023
# ...                                                 ...
# 6936  NY Sun, 9/9/1906, referring to account by Loui...
# 6937  NY Sun, 9/9/1906, referring to account by Loui...
# 6938  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 6939                   H. Taunton; N. Bartlett,  p. 234
# 6940              H. Taunton; N. Bartlett,  pp. 233-234
#
#                                     pdf  \
# 0                                   NaN
# 3                                   NaN
# 6                                   NaN
# 8                                   NaN
# 11                                  NaN
# ...                                 ...
# 6936   ND-0008-Fisherman2-Australia.pdf
# 6937  ND-0007 - Fisherman-Australia.pdf
# 6938       ND-0006-ArabBoy-Prymount.pdf
# 6939             ND-0005-RoebuckBay.pdf
# 6940                  ND-0004-Ahmun.pdf
#
#                                            href formula  \
# 0                                                   NaN
# 3                                                   NaN
# 6                                                   NaN
# 8                                                   NaN
# 11                                                  NaN
# ...                                                 ...
# 6936  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6937  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6938  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6939  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6940  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 0                                                   NaN         NaN
# 3                                                   NaN         NaN
# 6                                                   NaN         NaN
# 8                                                   NaN         NaN
# 11                                                  NaN         NaN
# ...                                                 ...         ...
# 6936  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0008
# 6937  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0007
# 6938  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0006
# 6939  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0005
# 6940  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0004
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0              NaN            NaN         NaN         NaN
# 3              NaN            NaN         NaN         NaN
# 6              NaN            NaN         NaN         NaN
# 8              NaN            NaN         NaN         NaN
# 11             NaN            NaN         NaN         NaN
# ...            ...            ...         ...         ...
# 6936       ND.0008            9.0         NaN         NaN
# 6937       ND.0007            8.0         NaN         NaN
# 6938       ND.0006            7.0         NaN         NaN
# 6939       ND.0005            6.0         NaN         NaN
# 6940       ND.0004            5.0         NaN         NaN
#
# [1591 rows x 23 columns]

# %%
df_filtered[df_filtered["Country"].isin(specific_countries)].isnull().sum()
# Out:
# Date                 0
# Year                 1
# Type                 2
# Country              0
# State               24
# Location            57
# Activity           137
# Name                27
# Sex                155
# Age                699
# Injury               9
# Unnamed: 11        132
# Time               826
# Species            667
# Source               2
# pdf                 36
# href formula        38
# href                37
# Case Number         37
# Case Number.1       37
# original order      37
# Unnamed: 21       1591
# Unnamed: 22       1590
# dtype: int64

# %%
df_filtered.columns = df_filtered.columns.str.strip()

counts_portugal = (df['Country'].str.lower() == 'portugal').value_counts()

df_filtered.drop(columns=['Name','Species','Sex','Unnamed: 11','Time','Source','pdf','href','href formula','original order','Case Number','Case Number.1','Unnamed: 21','Unnamed: 22','Type','Year','Age'], inplace=True)
df_filtered
# Out:
# /var/folders/s4/jp6nyhdj3ks3855w2gjshb2c0000gn/T/ipykernel_12101/1406670789.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop(columns=['Name','Species','Sex','Unnamed: 11','Time','Source','pdf','href','href formula','original order','Case Number','Case Number.1','Unnamed: 21','Unnamed: 22','Type','Year','Age'], inplace=True)
#              Date    Country              State  \
# 0     15 Mar 2024  Australia         Queensland
# 3     25 Feb-2024  Australia  Western Australia
# 6     29 Jan-2024  Australia   New  South Wales
# 8     09-Jan-2024  Australia    South Australia
# 11    29 Dec-2023     Mexico             Sonora
# ...           ...        ...                ...
# 6936  Before 1906  Australia                NaN
# 6937  Before 1906  Australia                NaN
# 6938  Before 1906  Australia    New South Wales
# 6939  Before 1903  Australia  Western Australia
# 6940  Before 1903  Australia  Western Australia
#
#                                 Location      Activity  \
# 0                          Bargara Beach      Swimming
# 3             Sandlnd Island, Jurian Bay           NaN
# 6           Elizabeth Bay, Sydney Harbor      Swimming
# 8                Walkers Beach, Elliston       Surfing
# 11    Tojahui Beach, Yavaros, Huatabampo   Free diving
# ...                                  ...           ...
# 6936                                 NaN       Fishing
# 6937                                 NaN       Fishing
# 6938                                          Swimming
# 6939                         Roebuck Bay        Diving
# 6940                                 NaN  Pearl diving
#
#                                         Injury
# 0     Minor injuries to back, abdomen and legs
# 3                                   Leg bitten
# 6                             Right leg bitten
# 8                                   Leg bitten
# 11                                       FATAL
# ...                                        ...
# 6936                                     FATAL
# 6937                                     FATAL
# 6938                                     FATAL
# 6939                                     FATAL
# 6940                                     FATAL
#
# [1591 rows x 6 columns]

# %%
counts_portugal = (df_filtered['Country'].str.lower().str.strip().str.replace(" ","") == 'portugal').value_counts()
counts_portugal
# Out:
# Country
# False    1587
# True        4
# Name: count, dtype: int64

# %%
counts_southafrica = (df_filtered['Country'].str.lower().str.strip().str.replace(" ","") == 'South africa').value_counts()
counts_southafrica
# Out:
# Country
# False    1591
# Name: count, dtype: int64

# %%
counts_mexico = (df_filtered['Country'].str.lower().str.strip().str.replace(" ","") == 'Mexico').value_counts()
counts_mexico
# Out:
# Country
# False    1591
# Name: count, dtype: int64

# %% [markdown]
# ### Australia

# %%
import pandas as pd


df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Unnamed: 11', 'Time', 'Species',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
# Remove spaces from column names
df.columns = df.columns.str.strip()

# Filter for specific countries and surfing activity in Australia
specific_countries = ["Australia"]
df_filtered = df[(df["Country"].isin(specific_countries)) & (df["Activity"] == "Surfing")].copy()

# Drop irrelevant columns 
columns_to_drop = ['Name', 'Species', 'Sex', 'Unnamed: 11', 'Time', 'Source', 'pdf', 
                   'href', 'href formula', 'original order', 'Case Number', 'Case Number.1', 
                   'Unnamed: 21', 'Unnamed: 22', 'Type', 'Age']
df_filtered.drop(columns=columns_to_drop, inplace=True)

# %%
# Create a 'isfatal' column: 1 if attack is fatal, 0 non fatal
df_filtered['isfatal'] = df_filtered['Injury'].apply(lambda x: 1 if isinstance(x, str) and 'fatal' in x.lower() else 0)
df_filtered['isfatal']
# Out:
# 8       0
# 12      1
# 13      0
# 28      1
# 46      0
#        ..
# 5287    0
# 5520    0
# 5547    0
# 5866    1
# 5911    0
# Name: isfatal, Length: 238, dtype: int64

# %%
australia_fatal = australia_attacks.groupby('Location').agg({'isfatal': 'sum'}).reset_index()
australia_fatal
# Out:
#                          Location  isfatal
# 0            7 Mile Beach, Gerroa        0
# 1                        Angourie        0
# 2            Arakoon's Little Bay        0
# 3                  Archie's Beach        0
# 4              Arrawarra Headland        0
# ..                            ...      ...
# 207                      Winkipop        0
# 208                Winkipop Beach        0
# 209  Woorim Beach, Bribie Island,        0
# 210                      Wurtulla        0
# 211                     Yallingup        0
#
# [212 rows x 2 columns]

# %%
final_australia_fatal = australia_attacks[['Date', 'Location']].merge(australia_fatal, on='Location', how='inner')

final_australia_fatal
# Out:
#             Date                           Location  isfatal
# 0    09-Jan-2024            Walkers Beach, Elliston        0
# 1    28 Dec-2023                        Ethel Beach        1
# 2    25 Dec-2023                            Old Bar        0
# 3    31 Oct-2023                        Streaky Bay        1
# 4    25 Aug 2023  Lighthouse Beach, Port Macquarie         0
# ..           ...                                ...      ...
# 232  14-Jan-1944               First Beach, Forster        0
# 233  05-Jan-1936              Main Beach, Southport        0
# 234  11-Mar-1935                          Newcastle        0
# 235  04-Jan-1922          Stockton Beach, Newcastle        0
# 236  22-Mar-1918                          Newcastle        0
#
# [237 rows x 3 columns]

# %%
final_australia_fatal.dropna(inplace=True)
final_australia_fatal
# Out:
#             Date                           Location  isfatal
# 0    09-Jan-2024            Walkers Beach, Elliston        0
# 1    28 Dec-2023                        Ethel Beach        1
# 2    25 Dec-2023                            Old Bar        0
# 3    31 Oct-2023                        Streaky Bay        1
# 4    25 Aug 2023  Lighthouse Beach, Port Macquarie         0
# ..           ...                                ...      ...
# 232  14-Jan-1944               First Beach, Forster        0
# 233  05-Jan-1936              Main Beach, Southport        0
# 234  11-Mar-1935                          Newcastle        0
# 235  04-Jan-1922          Stockton Beach, Newcastle        0
# 236  22-Mar-1918                          Newcastle        0
#
# [237 rows x 3 columns]

# %%
final_australia_fatal['Date'] = pd.to_datetime(final_australia_fatal['Date'], errors='coerce')
final_australia_fatal['Year'] = final_australia_fatal['Date'].dt.year
final_australia_fatal['Date']
# Out:
# 0     2024-01-09
# 1            NaT
# 2            NaT
# 3            NaT
# 4            NaT
#          ...
# 232   1944-01-14
# 233   1936-01-05
# 234   1935-03-11
# 235   1922-01-04
# 236   1918-03-22
# Name: Date, Length: 237, dtype: datetime64[ns]

# %%
final_australia_fatal['Year']
# Out:
# 0      2024.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 232    1944.0
# 233    1936.0
# 234    1935.0
# 235    1922.0
# 236    1918.0
# Name: Year, Length: 237, dtype: float64

# %%
attacks_by_location = final_australia_fatal.groupby(['Location', 'isfatal']).size().unstack(fill_value=0)
attacks_by_location.columns = ['Non Fatal Attacks', 'Fatal Attacks']
attacks_by_location
# Out:
#                               Non Fatal Attacks  Fatal Attacks
# Location
# 7 Mile Beach, Gerroa                          1              0
# Angourie                                      1              0
# Arakoon's Little Bay                          1              0
# Archie's Beach                                1              0
# Arrawarra Headland                            1              0
# ...                                         ...            ...
# Winkipop                                      1              0
# Winkipop Beach                                1              0
# Woorim Beach, Bribie Island,                  1              0
# Wurtulla                                      1              0
# Yallingup                                     1              0
#
# [212 rows x 2 columns]

# %%
safe_locations = attacks_by_location[attacks_by_location['Fatal Attacks'] == 0].sort_values(by='Non Fatal Attacks', ascending=True)
safe_locations
# Out:
#                                                     Non Fatal Attacks  \
# Location
# 7 Mile Beach, Gerroa                                                1
# Off North Bondi                                                     1
# Old Bar                                                             1
# Palm Beach                                                          1
# Pennington Bay, Kangaroo Island                                     1
# Phillip Island                                                      1
# Pincushion, north of Maroochydore Beach                             1
# Point Lonsdale                                                      1
# Point Lookout, Stradbroke Island                                    1
# Point Plomer                                                        1
# Point Sinclair, Cactus Beach near Penong                            1
# Port Campbell                                                       1
# Pyramids Beach                                                      1
# Pyramids Beach, Port Bouvard                                        1
# Red Bluff near Quobba Station                                       1
# Redgate Beach                                                       1
# Redhead Beach                                                       1
# Rottnest Island                                                     1
# Saltwater Beach                                                     1
# Sandbar Beach                                                       1
# Oak Beach                                                           1
# Sandon                                                              1
# Nun's Beach, Portland                                               1
# North Lancelin                                                      1
# Main Beach, Southport                                               1
# Maroochydore                                                        1
# Wurtulla                                                            1
# McMasters Beach, Central Coast                                      1
# Merewether Beach, Newcastle                                         1
# Middleton Point, Fleurieu Peninsula                                 1
# Moama Beach                                                         1
# Mona Vale Beach, Sydney                                             1
# Moonee Beach                                                        1
# Mullaway Headland                                                   1
# Nambucca                                                            1
# Nambucca River Entrance                                             1
# Nettley Bay                                                         1
# Newcastle Beach                                                     1
# Nobby's Beach                                                       1
# Noosa                                                               1
# Noraville                                                           1
# North Avoca Beach                                                   1
# North Cronulla Beach                                                1
# North Shelly Beach                                                  1
# Scarborough Beach, Perth                                            1
# Scotts Head                                                         1
# Seven Mile Beach, Byron Bay                                         1
# Trigg Beach                                                         1
# Trigg Beach, Perth                                                  1
# Tyrendarra Beach                                                    1
# Tyrendarra Beach near Portland                                      1
# Urunga area                                                         1
# Waitpinga                                                           1
# Waitpinga Beach, near Victor Harbor, Encounter Bay                  1
# Walkers Beach, Elliston                                             1
# Wallabi Point                                                       1
# Wamberal Beach                                                      1
# Wanda Beach                                                         1
# Warrnambool                                                         1
# Wategos Beach, Byon Bay                                             1
# Wilson's Promontory, Waratah Bay                                    1
# Windang Beach                                                       1
# Winki Pop, Bells Beach                                              1
# Winkipop                                                            1
# Winkipop Beach                                                      1
# Woorim Beach, Bribie Island,                                        1
# Town Beach, Port Macquarie                                          1
# Toms Surf break, Hamersley Pool, North Beach, P...                  1
# Thirteenth Beach                                                    1
# Terrigal Beach                                                      1
# Shelly Beach, Ballina                                               1
# Shelly Beach, Crescent Head                                         1
# Shelly Beach, Port Macquarie                                        1
# Shelly Point                                                        1
# South Broulee                                                       1
# South Cape Bay                                                      1
# South Golden Beach                                                  1
# South Narrabeen Beach                                               1
# South Steyne                                                        1
# Lucy's Beach                                                        1
# Southport                                                           1
# Stockton Beach                                                      1
# Stockton Beach, Newcastle                                           1
# Suffolk Park                                                        1
# Suicide Point, Point Leo                                            1
# Surfers Paradise Beach near Victor Harbour                          1
# Surfers Point, Phillip Island                                       1
# Surfers Point, Prevelly                                             1
# Tabourie Beach                                                      1
# Target Beach                                                        1
# Southside Beach, near Geelong                                       1
# Lipson Cove, Tumby Bay                                              1
# Yallingup                                                           1
# Lighthouse Beach, Port Macquarie                                    1
# Between Dee Why and Long Reef                                       1
# Coffin Bay                                                          1
# Conspicuous Beach, near Walpole                                     1
# Coolum Beach                                                        1
# Belongil Bay                                                        1
# Crowdy Baay                                                         1
# Bells Beach                                                         1
# Crowdy Head                                                         1
# Denmark                                                             1
# Duranbah, Greenmount Beach                                          1
# Lighthouse Beach, Seal Rocks                                        1
# Bateman's Bay                                                       1
# D’Estrees Bay near Kangaroo Island                                  1
# East Ballina                                                        1
# Elliston, Eyre Peninsula                                            1
# Falcon Bay Beach, Mandurah                                          1
# Avoca                                                               1
# Coffee Head                                                         1
# First Beach, Forster                                                1
# Cobblestones, Margaret River Area                                   1
# Clifton Beach                                                       1
# Bondi Beach, Sydney                                                 1
# Bondi, Sydney                                                       1
# Booti Booti National Park                                           1
# Blue Bay                                                            1
# Broken Head Beach                                                   1
# Bronte Beach                                                        1
# Broome Head                                                         1
# Birubi Point                                                        1
# Bunker Bay Beach                                                    1
# Binalong Bay                                                        1
# Cable Beach                                                         1
# Cactus Beach                                                        1
# Cactus Beach, near Ceduna                                           1
# Bherwerre Beach                                                     1
# Cathedral Rock                                                      1
# Cellito Beach                                                       1
# Clarks Beach, Byron Bay                                             1
# Clifton Beach, southwest of Hobart                                  1
# Bondi Beach                                                         1
# Fishery Bay                                                         1
# Flat Rock                                                           1
# Jimmy's Beach                                                       1
# Just north of Fingal Spit                                           1
# Avalon                                                              1
# Kangaroo Island                                                     1
# Kelpids Beach, Wylie Bay, Esperance                                 1
# Kilcunda                                                            1
# Kings Beach, Caloundra                                              1
# Lake Macquarie                                                      1
# Left break at the ‘Hot Spot’ at Sheringa Beach                      1
# Lefthanders Beach, Margaret River                                   1
# Lefthanders, Margaret River Area                                    1
# Arrawarra Headland                                                  1
# Archie's Beach                                                      1
# Arakoon's Little Bay                                                1
# Levys Beach                                                         1
# Angourie                                                            1
# Lighthouse Beach, Ballina                                           1
# Jan Juc Beach                                                       1
# Injidup                                                             1
# Iluka Beach                                                         1
# Horseshoe Bay, near Kempsey                                         1
# Flat Rock Beach, Lennox Head                                        1
# Flat Rock, Yamba                                                    1
# Flinders                                                            1
# Flinders, Mornington Penisula                                       1
# Floreat Beach                                                       1
# Fourth Beach / Twilgth Beach                                        1
# Fraser's Reef                                                       1
# Fishery Bay, Eyre Peninsula                                         1
# Gearys Beach                                                        1
# Gnarabup Beach                                                      1
# Goolwa Beach                                                        1
# Greenmount Beach                                                    1
# Guillotines surf break, Shire of Augusta Margar...                  1
# Gum Tree Bay                                                        1
# Happy Valley Beach, Caloundra                                       1
# Honeycombs, 250 km south of Perth                                   1
# Horseshoe Bay                                                       1
# Geelong                                                             1
# Bombo Beach                                                         1
# Avoca Beach                                                         2
# Maroubra                                                            2
# Sydney                                                              2
# Sunshine Beach                                                      2
# South Point, Gracetown                                              2
# Crescent Head                                                       2
# Shelly Beach, near Port Macquarie                                   2
# Seven Mile Beach, Gerroa                                            2
# Evans Head                                                          2
# Newcastle                                                           2
# Middleton Beach                                                     2
# Lennox Head, Ballina                                                2
# Lighthouse Beach                                                    2
# Broken Head                                                         2
# Tallow Beach, Byron Bay                                             3
# Fingal Beach                                                        3
# Sharpes Beach, Ballina                                              3
# Lennox Head                                                         4
#
#                                                     Fatal Attacks
# Location
# 7 Mile Beach, Gerroa                                            0
# Off North Bondi                                                 0
# Old Bar                                                         0
# Palm Beach                                                      0
# Pennington Bay, Kangaroo Island                                 0
# Phillip Island                                                  0
# Pincushion, north of Maroochydore Beach                         0
# Point Lonsdale                                                  0
# Point Lookout, Stradbroke Island                                0
# Point Plomer                                                    0
# Point Sinclair, Cactus Beach near Penong                        0
# Port Campbell                                                   0
# Pyramids Beach                                                  0
# Pyramids Beach, Port Bouvard                                    0
# Red Bluff near Quobba Station                                   0
# Redgate Beach                                                   0
# Redhead Beach                                                   0
# Rottnest Island                                                 0
# Saltwater Beach                                                 0
# Sandbar Beach                                                   0
# Oak Beach                                                       0
# Sandon                                                          0
# Nun's Beach, Portland                                           0
# North Lancelin                                                  0
# Main Beach, Southport                                           0
# Maroochydore                                                    0
# Wurtulla                                                        0
# McMasters Beach, Central Coast                                  0
# Merewether Beach, Newcastle                                     0
# Middleton Point, Fleurieu Peninsula                             0
# Moama Beach                                                     0
# Mona Vale Beach, Sydney                                         0
# Moonee Beach                                                    0
# Mullaway Headland                                               0
# Nambucca                                                        0
# Nambucca River Entrance                                         0
# Nettley Bay                                                     0
# Newcastle Beach                                                 0
# Nobby's Beach                                                   0
# Noosa                                                           0
# Noraville                                                       0
# North Avoca Beach                                               0
# North Cronulla Beach                                            0
# North Shelly Beach                                              0
# Scarborough Beach, Perth                                        0
# Scotts Head                                                     0
# Seven Mile Beach, Byron Bay                                     0
# Trigg Beach                                                     0
# Trigg Beach, Perth                                              0
# Tyrendarra Beach                                                0
# Tyrendarra Beach near Portland                                  0
# Urunga area                                                     0
# Waitpinga                                                       0
# Waitpinga Beach, near Victor Harbor, Encounter Bay              0
# Walkers Beach, Elliston                                         0
# Wallabi Point                                                   0
# Wamberal Beach                                                  0
# Wanda Beach                                                     0
# Warrnambool                                                     0
# Wategos Beach, Byon Bay                                         0
# Wilson's Promontory, Waratah Bay                                0
# Windang Beach                                                   0
# Winki Pop, Bells Beach                                          0
# Winkipop                                                        0
# Winkipop Beach                                                  0
# Woorim Beach, Bribie Island,                                    0
# Town Beach, Port Macquarie                                      0
# Toms Surf break, Hamersley Pool, North Beach, P...              0
# Thirteenth Beach                                                0
# Terrigal Beach                                                  0
# Shelly Beach, Ballina                                           0
# Shelly Beach, Crescent Head                                     0
# Shelly Beach, Port Macquarie                                    0
# Shelly Point                                                    0
# South Broulee                                                   0
# South Cape Bay                                                  0
# South Golden Beach                                              0
# South Narrabeen Beach                                           0
# South Steyne                                                    0
# Lucy's Beach                                                    0
# Southport                                                       0
# Stockton Beach                                                  0
# Stockton Beach, Newcastle                                       0
# Suffolk Park                                                    0
# Suicide Point, Point Leo                                        0
# Surfers Paradise Beach near Victor Harbour                      0
# Surfers Point, Phillip Island                                   0
# Surfers Point, Prevelly                                         0
# Tabourie Beach                                                  0
# Target Beach                                                    0
# Southside Beach, near Geelong                                   0
# Lipson Cove, Tumby Bay                                          0
# Yallingup                                                       0
# Lighthouse Beach, Port Macquarie                                0
# Between Dee Why and Long Reef                                   0
# Coffin Bay                                                      0
# Conspicuous Beach, near Walpole                                 0
# Coolum Beach                                                    0
# Belongil Bay                                                    0
# Crowdy Baay                                                     0
# Bells Beach                                                     0
# Crowdy Head                                                     0
# Denmark                                                         0
# Duranbah, Greenmount Beach                                      0
# Lighthouse Beach, Seal Rocks                                    0
# Bateman's Bay                                                   0
# D’Estrees Bay near Kangaroo Island                              0
# East Ballina                                                    0
# Elliston, Eyre Peninsula                                        0
# Falcon Bay Beach, Mandurah                                      0
# Avoca                                                           0
# Coffee Head                                                     0
# First Beach, Forster                                            0
# Cobblestones, Margaret River Area                               0
# Clifton Beach                                                   0
# Bondi Beach, Sydney                                             0
# Bondi, Sydney                                                   0
# Booti Booti National Park                                       0
# Blue Bay                                                        0
# Broken Head Beach                                               0
# Bronte Beach                                                    0
# Broome Head                                                     0
# Birubi Point                                                    0
# Bunker Bay Beach                                                0
# Binalong Bay                                                    0
# Cable Beach                                                     0
# Cactus Beach                                                    0
# Cactus Beach, near Ceduna                                       0
# Bherwerre Beach                                                 0
# Cathedral Rock                                                  0
# Cellito Beach                                                   0
# Clarks Beach, Byron Bay                                         0
# Clifton Beach, southwest of Hobart                              0
# Bondi Beach                                                     0
# Fishery Bay                                                     0
# Flat Rock                                                       0
# Jimmy's Beach                                                   0
# Just north of Fingal Spit                                       0
# Avalon                                                          0
# Kangaroo Island                                                 0
# Kelpids Beach, Wylie Bay, Esperance                             0
# Kilcunda                                                        0
# Kings Beach, Caloundra                                          0
# Lake Macquarie                                                  0
# Left break at the ‘Hot Spot’ at Sheringa Beach                  0
# Lefthanders Beach, Margaret River                               0
# Lefthanders, Margaret River Area                                0
# Arrawarra Headland                                              0
# Archie's Beach                                                  0
# Arakoon's Little Bay                                            0
# Levys Beach                                                     0
# Angourie                                                        0
# Lighthouse Beach, Ballina                                       0
# Jan Juc Beach                                                   0
# Injidup                                                         0
# Iluka Beach                                                     0
# Horseshoe Bay, near Kempsey                                     0
# Flat Rock Beach, Lennox Head                                    0
# Flat Rock, Yamba                                                0
# Flinders                                                        0
# Flinders, Mornington Penisula                                   0
# Floreat Beach                                                   0
# Fourth Beach / Twilgth Beach                                    0
# Fraser's Reef                                                   0
# Fishery Bay, Eyre Peninsula                                     0
# Gearys Beach                                                    0
# Gnarabup Beach                                                  0
# Goolwa Beach                                                    0
# Greenmount Beach                                                0
# Guillotines surf break, Shire of Augusta Margar...              0
# Gum Tree Bay                                                    0
# Happy Valley Beach, Caloundra                                   0
# Honeycombs, 250 km south of Perth                               0
# Horseshoe Bay                                                   0
# Geelong                                                         0
# Bombo Beach                                                     0
# Avoca Beach                                                     0
# Maroubra                                                        0
# Sydney                                                          0
# Sunshine Beach                                                  0
# South Point, Gracetown                                          0
# Crescent Head                                                   0
# Shelly Beach, near Port Macquarie                               0
# Seven Mile Beach, Gerroa                                        0
# Evans Head                                                      0
# Newcastle                                                       0
# Middleton Beach                                                 0
# Lennox Head, Ballina                                            0
# Lighthouse Beach                                                0
# Broken Head                                                     0
# Tallow Beach, Byron Bay                                         0
# Fingal Beach                                                    0
# Sharpes Beach, Ballina                                          0
# Lennox Head                                                     0

# %%
least_attacks_locations = safe_locations.head(10)
least_attacks_locations
# Out:
#                                          Non Fatal Attacks  Fatal Attacks
# Location
# 7 Mile Beach, Gerroa                                     1              0
# Off North Bondi                                          1              0
# Old Bar                                                  1              0
# Palm Beach                                               1              0
# Pennington Bay, Kangaroo Island                          1              0
# Phillip Island                                           1              0
# Pincushion, north of Maroochydore Beach                  1              0
# Point Lonsdale                                           1              0
# Point Lookout, Stradbroke Island                         1              0
# Point Plomer                                             1              0

# %%
plt.figure(figsize=(12, 8))
plt.barh(least_attacks_locations.index, least_attacks_locations['Non Fatal Attacks'], color='blue')
plt.xlabel("Number of Non-Fatal Attacks")
plt.ylabel("Location")
plt.title("Top 10 Beaches in Australia with the Least Non-Fatal Attacks and Zero Fatal Attacks")
plt.gca().invert_yaxis()
plt.show()

# %%
attacks_per_year = final_australia_fatal.groupby(['Year', 'isfatal']).size().unstack(fill_value=0)
attacks_per_year.columns = ['Non Fatal Attacks', 'Fatal Attacks']

# %%
plt.figure(figsize=(12, 6))
plt.plot(attacks_per_year.index, attacks_per_year['Non Fatal Attacks'], label='Non Fatal Attacks', marker='o')
plt.plot(attacks_per_year.index, attacks_per_year['Fatal Attacks'], label='Fatal Attacks', marker='o', color='red')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('Evolution of Fatal and Non-Fatal Shark Attacks Over Time in Australia')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Bondi Beach, New South Wales - Listed as "Off North Bondi" in your data (safe with 0 fatal attacks)
# Phillip Island - Appears in your safe locations with 0 fatal attacks
# Point Lookout, Stradbroke Island - Matches "Stradbroke Island," noted for surfing potential, with no fatal attacks in your list

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert the 'Date' column to datetime and extract the year
final_australia_fatal['Date'] = pd.to_datetime(final_australia_fatal['Date'], errors='coerce')
final_australia_fatal['Year'] = final_australia_fatal['Date'].dt.year

# Group data by location and fatality
attacks_by_location = final_australia_fatal.groupby(['Location', 'isfatal']).size().unstack(fill_value=0)
attacks_by_location.columns = ['Non Fatal Attacks', 'Fatal Attacks']

# Filter to get only beaches with zero fatal attacks
safe_locations = attacks_by_location[attacks_by_location['Fatal Attacks'] == 0].sort_values(by='Non Fatal Attacks', ascending=True)

# Select the 10 locations with the least non-fatal attacks 
least_attacks_locations = safe_locations.head(10)

plt.figure(figsize=(12, 8))
plt.barh(least_attacks_locations.index, least_attacks_locations['Non Fatal Attacks'], color='blue')
plt.xlabel("Number of Non-Fatal Attacks")
plt.ylabel("Location")
plt.title("Top 10 Beaches in Australia with the Least Non-Fatal Attacks (and No Fatal Attacks)")
plt.gca().invert_yaxis()  # Invert y-axis for easier reading
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


final_australia_fatal['Date'] = pd.to_datetime(final_australia_fatal['Date'], errors='coerce')
final_australia_fatal['Year'] = final_australia_fatal['Date'].dt.year

# Analyze the safest beaches with no fatal attacks
attacks_by_location = final_australia_fatal.groupby(['Location', 'isfatal']).size().unstack(fill_value=0)
attacks_by_location.columns = ['Non Fatal Attacks', 'Fatal Attacks']

# Filter locations with zero fatal attacks
safe_locations = attacks_by_location[attacks_by_location['Fatal Attacks'] == 0].sort_values(by='Non Fatal Attacks', ascending=True)

# Select the top 10 locations with the least non-fatal attacks
least_attacks_locations = safe_locations.head(10)

# Plotting the bar chart for locations with the least non-fatal attacks 
plt.figure(figsize=(12, 8))
plt.barh(least_attacks_locations.index, least_attacks_locations['Non Fatal Attacks'], color='blue')
plt.xlabel("Number of Non-Fatal Attacks")
plt.ylabel("Location")
plt.title("Top 10 Beaches in Australia with the Least Non-Fatal Attacks (and No Fatal Attacks)")
plt.gca().invert_yaxis()  # Invert y-axis for easier reading
plt.show()

# Group data by year and fatality
attacks_per_year = final_australia_fatal.groupby(['Year', 'isfatal']).size().unstack(fill_value=0)
attacks_per_year.columns = ['Non Fatal Attacks', 'Fatal Attacks']

# Plotting the time series for fatal and non-fatal attacks
plt.figure(figsize=(12, 6))
plt.plot(attacks_per_year.index, attacks_per_year['Non Fatal Attacks'], label='Non Fatal Attacks', marker='o')
plt.plot(attacks_per_year.index, attacks_per_year['Fatal Attacks'], label='Fatal Attacks', marker='o', color='red')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('Evolution of Fatal and Non-Fatal Shark Attacks Over Time in Australia')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# From both lists, here are the beaches in Australia that overlap and could be suitable for a surf school due to their popularity and beginner-friendly characteristics:
#
# - Bondi Beach, New South Walesa
#
# - 7 Mile Beach, Gerroa

# %% [markdown]
# ### Mexico

# %%
mexico_attacks = df[(df['Country'] == 'Mexico') & (df['Activity'].str.contains('surfing', case=False, na=False))].copy()

mexico_attacks['isfatal'] = mexico_attacks['Injury'].apply(lambda x: 1 if 'fatal' in str(x).lower() else 0)

mexico_fatal = mexico_attacks.groupby('Location').agg({'isfatal': 'sum'}).reset_index()
final_mexico_fatal = mexico_attacks[['Date', 'Location']].merge(mexico_fatal, on='Location', how='inner')
final_mexico_fatal.dropna(subset=['Date'], inplace=True)
final_mexico_fatal['Date'] = pd.to_datetime(final_mexico_fatal['Date'], errors='coerce')
final_mexico_fatal['Year'] = final_mexico_fatal['Date'].dt.year

attacks_by_location_mex = final_mexico_fatal.groupby(['Location', 'isfatal']).size().unstack(fill_value=0)
attacks_by_location_mex.columns = ['Non Fatal Attacks', 'Fatal Attacks']
safe_locations_mex = attacks_by_location_mex[attacks_by_location_mex['Fatal Attacks'] == 0].sort_values(by='Non Fatal Attacks', ascending=True).head(10)

plt.figure(figsize=(12, 8))
plt.barh(safe_locations_mex.index, safe_locations_mex['Non Fatal Attacks'], color='blue')
plt.xlabel("Number of Non-Fatal Attacks")
plt.ylabel("Location")
plt.title("Top 10 Beaches in Mexico with the Least Non-Fatal Attacks (and No Fatal Attacks)")
plt.gca().invert_yaxis()
plt.show()

# %%
# Group data by year and fatality for Mexico
attacks_per_year_mex = final_mexico_fatal.groupby(['Year', 'isfatal']).size().unstack(fill_value=0)
attacks_per_year_mex.columns = ['Non Fatal Attacks', 'Fatal Attacks']

# Plotting the time series for Mexico
plt.figure(figsize=(12, 6))
plt.plot(attacks_per_year_mex.index, attacks_per_year_mex['Non Fatal Attacks'], label='Non Fatal Attacks', marker='o')
plt.plot(attacks_per_year_mex.index, attacks_per_year_mex['Fatal Attacks'], label='Fatal Attacks', marker='o', color='red')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('Evolution of Fatal and Non-Fatal Shark Attacks Over Time in Mexico')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### South Africa

# %%
# Strip whitespace from column names
df.columns = df.columns.str.strip()

south_africa_attacks = df[(df['Country'].str.strip().str.lower() == 'south africa') & 
                          (df['Activity'].str.strip().str.lower() == 'surfing')].copy()

# Create 'isfatal' column based on the 'Injury' column
south_africa_attacks['isfatal'] = south_africa_attacks['Injury'].apply(lambda x: 1 if 'FATAL' in str(x).upper() else 0)

# Convert 'Date' to datetime format and extract year
south_africa_attacks['Date'] = pd.to_datetime(south_africa_attacks['Date'], errors='coerce')
south_africa_attacks['Year'] = south_africa_attacks['Date'].dt.year

# Group by Location and sum fatalities
south_africa_fatal = south_africa_attacks.groupby('Location').agg({'isfatal': 'sum'}).reset_index()

# Merge with original data to keep dates
final_south_africa_fatal = south_africa_attacks[['Date', 'Location']].merge(
    south_africa_fatal, on='Location', how='inner'
)

final_south_africa_fatal.dropna(inplace=True)

# Calculate attacks by year and fatality type
attacks_per_year = final_south_africa_fatal.groupby(['Date', 'isfatal']).size().unstack(fill_value=0)
attacks_per_year.columns = ['Non Fatal Attacks', 'Fatal Attacks']

# Plot time series for South Africa
plt.figure(figsize=(12, 6))
plt.plot(attacks_per_year.index, attacks_per_year['Non Fatal Attacks'], label='Non Fatal Attacks', marker='o')
plt.plot(attacks_per_year.index, attacks_per_year['Fatal Attacks'], label='Fatal Attacks', marker='o', color='red')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('Evolution of Fatal and Non-Fatal Shark Attacks Over Time in South Africa')
plt.legend()
plt.grid(True)
plt.show()


# Sort the top 10 beaches with the fewest non-fatal attacks
top_safe_locations = safe_locations_non_fatal_count.sort_values(by='NonFatalCount', ascending=True).head(10)

# Plot the bar chart with enhanced readability
plt.figure(figsize=(14, 8))
plt.barh(top_safe_locations['Location'], top_safe_locations['NonFatalCount'], color='blue')
plt.xlabel("Number of Non-Fatal Attacks")
plt.ylabel("Location")
plt.title("Top 10 Safe Beaches in South Africa with the Fewest Non-Fatal Shark Attacks")
plt.gca().invert_yaxis()  # Invert y-axis for easier reading

# Font size 
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
print(top_safe_locations)
# Out:
#                           Location  NonFatalCount
# 32  Lookout Beach, Plettenberg Bay              1
# 31                         LaMercy              1
# 63         West Beach, Port Alfred              1
# 33                Melkbaai, Strand              1
# 35                      Muizenberg              1
# 36           Muizenberg, False Bay              1
# 39        Nahoon Reef, East London              1
# 42             North Beach, Durban              1
# 43                   Ntlonyane Bay              1
# 44                 Plettenberg Bay              1

# %%
# Filter safe locations with at least one non-fatal attack
safe_locations_with_non_fatal = south_africa_attacks[south_africa_attacks['isfatal'] == 0]
safe_locations_non_fatal_count = safe_locations_with_non_fatal.groupby('Location').size().reset_index(name='NonFatalCount')

# Sort the DataFrame in ascending order by NonFatalCount
safe_locations_non_fatal_count_sorted = safe_locations_non_fatal_count.sort_values(by='NonFatalCount', ascending=True)

# Display the sorted DataFrame
print("Safe Locations with Non-Fatal Attacks (Ascending Order):\n", safe_locations_non_fatal_count_sorted)
# Out:
# Safe Locations with Non-Fatal Attacks (Ascending Order):
#                                        Location  NonFatalCount
# 32              Lookout Beach, Plettenberg Bay              1
# 31                                     LaMercy              1
# 63                     West Beach, Port Alfred              1
# 33                            Melkbaai, Strand              1
# 35                                  Muizenberg              1
# 36                       Muizenberg, False Bay              1
# 39                    Nahoon Reef, East London              1
# 42                         North Beach, Durban              1
# 43                               Ntlonyane Bay              1
# 44                             Plettenberg Bay              1
# 45                               Pollock Beach              1
# 46               Pollock Beach, Port Elizabeth              1
# 47                                Qolera River              1
# 49                               Robberg Beach              1
# 50                  Sandstrand, Jongensfontein              1
# 51                Seal Point, Cape St. Francis              1
# 52                             South of Durban              1
# 54                                    Stil Bay              1
# 55                                   Still Bay              1
# 56                    Supertubes, Jeffreys Bay              1
# 57      Surfers' Corner, Muizenberg, False Bay              1
# 58     The Fence, King's Beach, Port Elizabeth              1
# 59                       The Steps, Wilderness              1
# 60                                  The Strand              1
# 61                                Umbogintwini              1
# 62                                  Umtentweni              1
# 30                                    Kogebaai              1
# 29                                King’s Beach              1
# 64                          Yellow Sands Point              1
# 27                  Keurbooms, Plettenberg Bay              1
# 1                     Beachview Holiday Resort              1
# 2                                    Bonza Bay              1
# 5                           Chintsa East Beach              1
# 6                     Cintsa East, East London              1
# 7                    Cintza Beach, East London              1
# 8                                  Danger Reef              1
# 9                                    Die Platt              1
# 10  Duck Pond, Sardina Bay near Port Elizabeth              1
# 11                                      Durban              1
# 14                                Fuller’s Bay              1
# 28                King's Beach, Port Elizabeth              1
# 16                                  Glenashley              1
# 17                                  Glengariff              1
# 15                               Garvies Beach              1
# 19                               Hawston Beach              1
# 26                             Kei River Mouth              1
# 25                     Jogensfontein, Stilbaai              1
# 24                               Jeffrey’s Bay              1
# 18                         Gonubie River Mouth              1
# 21                                    Isipingo              1
# 12                     East Beach, Port Alfred              2
# 38                   Nahoon Beach, East London              2
# 53                             St. Francis Bay              2
# 48                             Queensberry Bay              2
# 23                                Jeffreys Bay              2
# 20                   Inyoni Rocks, Amanzimtoti              2
# 3                                  Cape Recife              2
# 41                                   Noordhoek              2
# 0                                  Amanzimtoti              2
# 22                               Jeffrey's Bay              3
# 34                                  Mossel Bay              3
# 4                             Cape St. Francis              3
# 13                                 East London              3
# 37                                      Nahoon              5
# 40                         Nahoon, East London              7

# %%
safe_locations = south_africa_fatal[south_africa_fatal['isfatal'] == 0]
safe_locations
# Out:
#                                       Location  isfatal
# 0                                  Amanzimtoti        0
# 1                     Beachview Holiday Resort        0
# 2                                    Bonza Bay        0
# 4                                  Cape Recife        0
# 5                             Cape St. Francis        0
# 6                           Chintsa East Beach        0
# 7                     Cintsa East, East London        0
# 8                    Cintza Beach, East London        0
# 9                                  Danger Reef        0
# 10                                   Die Platt        0
# 11  Duck Pond, Sardina Bay near Port Elizabeth        0
# 12                                      Durban        0
# 13                     East Beach, Port Alfred        0
# 14                                 East London        0
# 15                                Fuller’s Bay        0
# 16                               Garvies Beach        0
# 17                                  Glenashley        0
# 18                                  Glengariff        0
# 20                         Gonubie River Mouth        0
# 21                               Hawston Beach        0
# 23                   Inyoni Rocks, Amanzimtoti        0
# 24                                    Isipingo        0
# 25                               Jeffrey's Bay        0
# 26                                Jeffreys Bay        0
# 27                               Jeffrey’s Bay        0
# 28                     Jogensfontein, Stilbaai        0
# 29                             Kei River Mouth        0
# 30                  Keurbooms, Plettenberg Bay        0
# 31                King's Beach, Port Elizabeth        0
# 32                                King’s Beach        0
# 33                                    Kogebaai        0
# 34                                     LaMercy        0
# 35              Lookout Beach, Plettenberg Bay        0
# 37                            Melkbaai, Strand        0
# 38                                  Mossel Bay        0
# 39                                  Muizenberg        0
# 40                       Muizenberg, False Bay        0
# 41                                      Nahoon        0
# 43                    Nahoon Reef, East London        0
# 44                         Nahoon, East London        0
# 45                                   Noordhoek        0
# 46                         North Beach, Durban        0
# 48                               Ntlonyane Bay        0
# 49                             Plettenberg Bay        0
# 50                               Pollock Beach        0
# 51               Pollock Beach, Port Elizabeth        0
# 52                                Qolera River        0
# 53                             Queensberry Bay        0
# 54                               Robberg Beach        0
# 55                  Sandstrand, Jongensfontein        0
# 56                Seal Point, Cape St. Francis        0
# 58                             South of Durban        0
# 59                             St. Francis Bay        0
# 60                                    Stil Bay        0
# 61                                   Still Bay        0
# 62                    Supertubes, Jeffreys Bay        0
# 63      Surfers' Corner, Muizenberg, False Bay        0
# 64     The Fence, King's Beach, Port Elizabeth        0
# 65                       The Steps, Wilderness        0
# 66                                  The Strand        0
# 67                                Umbogintwini        0
# 68                                  Umtentweni        0
# 69                     West Beach, Port Alfred        0
# 70                          Yellow Sands Point        0

# %%
# List of safe beaches with non-fatal attacks in South Africa
safe_beaches = [
    "Lookout Beach, Plettenberg Bay", "LaMercy", "West Beach, Port Alfred", "Melkbaai, Strand",
    "Muizenberg", "Muizenberg, False Bay", "Nahoon Reef, East London", "North Beach, Durban",
    "Ntlonyane Bay", "Plettenberg Bay", "Pollock Beach", "Pollock Beach, Port Elizabeth",
    "Qolera River", "Robberg Beach", "Sandstrand, Jongensfontein", "Seal Point, Cape St. Francis",
    "South of Durban", "Stil Bay", "Still Bay", "Supertubes, Jeffreys Bay",
    "Surfers' Corner, Muizenberg, False Bay", "The Fence, King's Beach, Port Elizabeth",
    "The Steps, Wilderness", "The Strand", "Umbogintwini", "Umtentweni", "Kogebaai",
    "King’s Beach", "Yellow Sands Point", "Keurbooms, Plettenberg Bay", 
    "Beachview Holiday Resort", "Bonza Bay", "Chintsa East Beach"
]

# List of recommended surf beaches
recommended_surf_beaches = [
    "Jeffreys Bay, Eastern Cape", "Muizenberg, Western Cape", "Durban, KwaZulu-Natal",
    "Dungeons, Hout Bay, Western Cape", "Victoria Bay, Garden Route"
]

# Finding common beaches 
common_beaches = [
    safe_beach for safe_beach in safe_beaches
    if any(recommended_beach.split(',')[0] in safe_beach for recommended_beach in recommended_surf_beaches)
]

print("Beaches suitable for surfing with low or no non-fatal shark attacks:\n", common_beaches)
# Out:
# Beaches suitable for surfing with low or no non-fatal shark attacks:
#  ['Muizenberg', 'Muizenberg, False Bay', 'North Beach, Durban', 'South of Durban', 'Supertubes, Jeffreys Bay', "Surfers' Corner, Muizenberg, False Bay"]

# %% [markdown]
# or a beginner-friendly surfing school, Muizenberg (including Surfers' Corner) would be the top choice. It combines a safe environment, ideal wave conditions for learning, and an established surfing community.
#
# If you’re looking for a broader audience, North Beach in Durban is another excellent option due to its consistency, warm water, and beach amenities that attract surfers of all levels.

# %% [markdown]
# ### Portugal

# %%
df['Country'] = df['Country'].str.strip().str.title()

portugal_attacks = df[df['Country'] == 'Portugal'][['Location', 'Injury']].dropna()

portugal_attacks['isfatal'] = portugal_attacks['Injury'].apply(lambda x: 1 if 'FATAL' in str(x).upper() else 0)

portugal_summary = portugal_attacks.groupby('Location')['isfatal'].agg(
    NonFatalCount=lambda x: (x == 0).sum(),
    FatalCount=lambda x: (x == 1).sum()
).reset_index()

print("Portugal Locations with Fatal and Non-Fatal Shark Attacks:")
portugal_summary
# Out:
# Portugal Locations with Fatal and Non-Fatal Shark Attacks:
#                     Location  NonFatalCount  FatalCount
# 0    9 nm off Vila do Conde               1           0
# 1                Off Funchal              0           1
# 2  Sao Jorge, Madeira Island              0           1
# 3                      Sines              1           0

# %% [markdown]
# Ericeira, Ribeira d’Ilhas: Good for all levels and is a World Surfing Reserve.
